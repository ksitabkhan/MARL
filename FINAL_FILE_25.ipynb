# %% [markdown]
# <h1>RL For waste collection</h1>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from math import sin, cos, sqrt, atan2, radians
import random

# %%
from google.colab import drive
 
drive.mount('/content/drive')

# %cd /content/drive/My Drive/Colab Notebooks/Project
# ISOT_real = pd.read_csv('ISOT_True.csv')')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/Project

# %%
position = pd.read_csv('dlrrefusebinslocations.csv',encoding='latin1')


# assigning random values for weight of waste in the bin
weights = (np.random.choice(range(0,300), size=len(position), replace=True))/10
position['weight']=weights

#The depot coordinates are stored in the CSV file. Coordinates obtained from Google 
depot = pd.read_csv('Depot.csv',encoding='latin1')

position= position.append(depot, ignore_index=True)

my_df = position.sort_values(by=['Bin no.'],ignore_index=True)
my_df
# Out:
#                                            Description  ...  weight
# 0                                            DLR Depot  ...     0.0
# 1                   AA - 1 - Foxrock Park, opposite 28  ...     9.2
# 2    AB - 2 - Foxrock Ave, beside lane opposite 59a...  ...    28.4
# 3                  AC - 3 - Foxrock Ave, outside shops  ...    23.0
# 4      AD - 4 - Kill Lane, outside Deansgrange library  ...    20.3
# ..                                                 ...  ...     ...
# 394  OTA - 395 - Bird Avenue, green area on front o...  ...    26.1
# 395  KFA - 396 - St. Raphaels Road, at bus stop bes...  ...    16.2
# 396        MVA - 397 - Chruchtown Road, at Luas bridge  ...    20.7
# 397       HKA - 398 - Arnold Park, at entrance to park  ...     3.3
# 398  HJA - 399 - Sallyglen Road - Dalkey School pro...  ...     4.9
#
# [399 rows x 5 columns]

# %%
my_df=my_df.head(n=26)
LEN=(len(my_df))
print(LEN)
# Out:
# 26

# %%
sum(my_df['weight'])
# Out:
# 431.59999999999997

# %%
#Roughly displaying the location of all the bins(blue) and depot (red) 
plt.plot(my_df['Longitude'][0], my_df['Latitude'][0], c='r', marker='s')
plt.scatter(my_df['Longitude'][1:], my_df['Latitude'][1:], c='b',s=5)

# %%
distance= np.zeros(len(my_df)*len(my_df)).reshape(len(my_df), len(my_df))

# %%
R = 6373.0 # approximate radius of earth in km
for i in range (0,len(my_df)):
    for j in range(0,len(my_df)):
        if i == j:
            distance[i,j]=float('inf')
        else : 
            lat1 = radians(my_df["Latitude"][i])
            lon1 = radians(my_df["Longitude"][i])
            lat2 = radians(my_df["Latitude"][j])
            lon2 = radians(my_df["Longitude"][j])
            dlon = lon2 - lon1
            dlat = lat2 - lat1
            a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
            c = 2 * atan2(sqrt(a), sqrt(1 - a))

            distance[i,j] = round(R * c ,4)
#             print("\n")

# %%
print(f"Shape of the distance matrix is: {distance.shape}")
# Out:
# Shape of the distance matrix is: (26, 26)

# %%
distance
# Out:
# array([[   inf, 3.364 , 3.4434, 3.3851, 2.8857, 2.8347, 2.7806, 2.7835,
#         2.756 , 2.783 , 2.7847, 2.7748, 3.2888, 2.4171, 2.3168, 2.2876,
#         1.5776, 1.5623, 1.889 , 2.2939, 1.8289, 1.9553, 1.9928, 1.9958,
#         1.6123, 1.4073],
#        [3.364 ,    inf, 0.2611, 0.231 , 0.4783, 0.5295, 0.5837, 0.5825,
#         0.6087, 0.5876, 0.737 , 0.9829, 0.9146, 0.9914, 1.0688, 1.0822,
#         1.7864, 1.8071, 1.5857, 1.3947, 2.2653, 2.2777, 2.2683, 2.2825,
#         2.0703, 2.7837],
#        [3.4434, 0.2611,    inf, 0.0607, 0.6068, 0.6449, 0.7071, 0.7153,
#         0.7152, 0.6745, 0.6993, 0.8794, 0.6953, 1.0299, 1.1266, 1.1595,
#         1.8726, 1.8812, 1.6059, 1.3467, 2.2116, 2.2085, 2.1951, 2.2085,
#         2.0621, 2.7568],
#        [3.3851, 0.231 , 0.0607,    inf, 0.5464, 0.5842, 0.6465, 0.6549,
#         0.6546, 0.6141, 0.6496, 0.843 , 0.6953, 0.9731, 1.0685, 1.1002,
#         1.8134, 1.8228, 1.5519, 1.3015, 2.1687, 2.1683, 2.1556, 2.1692,
#         2.0121, 2.71  ],
#        [2.8857, 0.4783, 0.6068, 0.5464,    inf, 0.0556, 0.1057, 0.109 ,
#         0.134 , 0.1362, 0.4416, 0.7448, 0.9433, 0.5456, 0.6049, 0.6083,
#         1.3082, 1.3303, 1.1363, 1.024 , 1.8752, 1.9065, 1.9025, 1.9175,
#         1.6366, 2.3596],
#        [2.8347, 0.5295, 0.6449, 0.5842, 0.0556,    inf, 0.0629, 0.0782,
#         0.0796, 0.0846, 0.4075, 0.711 , 0.939 , 0.4902, 0.5496, 0.5544,
#         1.2571, 1.2778, 1.0807, 0.9729, 1.8216, 1.854 , 1.8504, 1.8655,
#         1.5811, 2.3042],
#        [2.7806, 0.5837, 0.7071, 0.6465, 0.1057, 0.0629,    inf, 0.027 ,
#         0.0496, 0.0982, 0.4323, 0.7333, 0.9889, 0.4613, 0.5096, 0.5069,
#         1.2032, 1.2264, 1.0445, 0.9618, 1.8006, 1.8373, 1.835 , 1.8502,
#         1.5488, 2.2734],
#        [2.7835, 0.5825, 0.7153, 0.6549, 0.109 , 0.0782, 0.027 ,    inf,
#         0.075 , 0.125 , 0.4593, 0.7602, 1.0127, 0.4794, 0.5229, 0.516 ,
#         1.2067, 1.2317, 1.0588, 0.9844, 1.8202, 1.8582, 1.8562, 1.8715,
#         1.5644, 2.2894],
#        [2.756 , 0.6087, 0.7152, 0.6546, 0.134 , 0.0796, 0.0496, 0.075 ,
#            inf, 0.061 , 0.3885, 0.6876, 0.9597, 0.4168, 0.4713, 0.4749,
#         1.1784, 1.1985, 1.004 , 0.9128, 1.7538, 1.7895, 1.7869, 1.8021,
#         1.5063, 2.2303],
#        [2.783 , 0.5876, 0.6745, 0.6141, 0.1362, 0.0846, 0.0982, 0.125 ,
#         0.061 ,    inf, 0.3345, 0.6363, 0.8987, 0.4135, 0.4818, 0.4963,
#         1.2064, 1.2225, 1.0072, 0.8885, 1.7391, 1.7704, 1.7665, 1.7816,
#         1.5042, 2.2261],
#        [2.7847, 0.737 , 0.6993, 0.6496, 0.4416, 0.4075, 0.4323, 0.4593,
#         0.3885, 0.3345,    inf, 0.3036, 0.6318, 0.3863, 0.5025, 0.5677,
#         1.2444, 1.236 , 0.9154, 0.6593, 1.5303, 1.5407, 1.5315, 1.5458,
#         1.3628, 2.0617],
#        [2.7748, 0.9829, 0.8794, 0.843 , 0.7448, 0.711 , 0.7333, 0.7602,
#         0.6876, 0.6363, 0.3036,    inf, 0.5164, 0.5376, 0.6488, 0.7333,
#         1.309 , 1.2799, 0.8879, 0.5083, 1.3435, 1.3319, 1.3173, 1.3304,
#         1.252 , 1.9078],
#        [3.2888, 0.9146, 0.6953, 0.6953, 0.9433, 0.939 , 0.9889, 1.0127,
#         0.9597, 0.8987, 0.6318, 0.5164,    inf, 0.997 , 1.1149, 1.1895,
#         1.818 , 1.793 , 1.404 , 1.0038, 1.7687, 1.7298, 1.7079, 1.7188,
#         1.7405, 2.3538],
#        [2.4171, 0.9914, 1.0299, 0.9731, 0.5456, 0.4902, 0.4613, 0.4794,
#         0.4168, 0.4135, 0.3863, 0.5376, 0.997 ,    inf, 0.1181, 0.1965,
#         0.8613, 0.8587, 0.595 , 0.5322, 1.342 , 1.3846, 1.3844, 1.3998,
#         1.091 , 1.814 ],
#        [2.3168, 1.0688, 1.1266, 1.0685, 0.6049, 0.5496, 0.5096, 0.5229,
#         0.4713, 0.4818, 0.5025, 0.6488, 1.1149, 0.1181,    inf, 0.0889,
#         0.752 , 0.7551, 0.5363, 0.5677, 1.3258, 1.3795, 1.3826, 1.3981,
#         1.0445, 1.7702],
#        [2.2876, 1.0822, 1.1595, 1.1002, 0.6083, 0.5544, 0.5069, 0.516 ,
#         0.4749, 0.4963, 0.5677, 0.7333, 1.1895, 0.1965, 0.0889,    inf,
#         0.7132, 0.7263, 0.5624, 0.6465, 1.3748, 1.4349, 1.4398, 1.4554,
#         1.0737, 1.7984],
#        [1.5776, 1.7864, 1.8726, 1.8134, 1.3082, 1.2571, 1.2032, 1.2067,
#         1.1784, 1.2064, 1.2444, 1.309 , 1.818 , 0.8613, 0.752 , 0.7132,
#            inf, 0.09  , 0.4998, 0.937 , 1.1612, 1.2756, 1.2982, 1.3122,
#         0.7496, 1.3608],
#        [1.5623, 1.8071, 1.8812, 1.8228, 1.3303, 1.2778, 1.2264, 1.2317,
#         1.1985, 1.2225, 1.236 , 1.2799, 1.793 , 0.8587, 0.7551, 0.7263,
#         0.09  ,    inf, 0.4385, 0.8835, 1.0715, 1.1864, 1.2093, 1.2232,
#         0.6596, 1.2778],
#        [1.889 , 1.5857, 1.6059, 1.5519, 1.1363, 1.0807, 1.0445, 1.0588,
#         1.004 , 1.0072, 0.9154, 0.8879, 1.404 , 0.595 , 0.5363, 0.5624,
#         0.4998, 0.4385,    inf, 0.4479, 0.8379, 0.9188, 0.931 , 0.9464,
#         0.5112, 1.2363],
#        [2.2939, 1.3947, 1.3467, 1.3015, 1.024 , 0.9729, 0.9618, 0.9844,
#         0.9128, 0.8885, 0.6593, 0.5083, 1.0038, 0.5322, 0.5677, 0.6465,
#         0.937 , 0.8835, 0.4479,    inf, 0.871 , 0.8868, 0.8806, 0.8954,
#         0.7438, 1.4117],
#        [1.8289, 2.2653, 2.2116, 2.1687, 1.8752, 1.8216, 1.8006, 1.8202,
#         1.7538, 1.7391, 1.5303, 1.3435, 1.7687, 1.342 , 1.3258, 1.3748,
#         1.1612, 1.0715, 0.8379, 0.871 ,    inf, 0.137 , 0.1724, 0.1803,
#         0.4151, 0.592 ],
#        [1.9553, 2.2777, 2.2085, 2.1683, 1.9065, 1.854 , 1.8373, 1.8582,
#         1.7895, 1.7704, 1.5407, 1.3319, 1.7298, 1.3846, 1.3795, 1.4349,
#         1.2756, 1.1864, 0.9188, 0.8868, 0.137 ,    inf, 0.0375, 0.0433,
#         0.5387, 0.669 ],
#        [1.9928, 2.2683, 2.1951, 2.1556, 1.9025, 1.8504, 1.835 , 1.8562,
#         1.7869, 1.7665, 1.5315, 1.3173, 1.7079, 1.3844, 1.3826, 1.4398,
#         1.2982, 1.2093, 0.931 , 0.8806, 0.1724, 0.0375,    inf, 0.0156,
#         0.5663, 0.7021],
#        [1.9958, 2.2825, 2.2085, 2.1692, 1.9175, 1.8655, 1.8502, 1.8715,
#         1.8021, 1.7816, 1.5458, 1.3304, 1.7188, 1.3998, 1.3981, 1.4554,
#         1.3122, 1.2232, 0.9464, 0.8954, 0.1803, 0.0433, 0.0156,    inf,
#         0.5787, 0.6977],
#        [1.6123, 2.0703, 2.0621, 2.0121, 1.6366, 1.5811, 1.5488, 1.5644,
#         1.5063, 1.5042, 1.3628, 1.252 , 1.7405, 1.091 , 1.0445, 1.0737,
#         0.7496, 0.6596, 0.5112, 0.7438, 0.4151, 0.5387, 0.5663, 0.5787,
#            inf, 0.7258],
#        [1.4073, 2.7837, 2.7568, 2.71  , 2.3596, 2.3042, 2.2734, 2.2894,
#         2.2303, 2.2261, 2.0617, 1.9078, 2.3538, 1.814 , 1.7702, 1.7984,
#         1.3608, 1.2778, 1.2363, 1.4117, 0.592 , 0.669 , 0.7021, 0.6977,
#         0.7258,    inf]])

# %%
def prepPlot(FINAL_ROUTE):
    i=0
    d={}
    d1={}
    for key in FINAL_ROUTE:
        x=[]
        y=[]
        var1='x'+str(key)
        var2='y'+str(key)
        d1[key]=list([var1,var2])
        listed= FINAL_ROUTE[key]
        for i in listed:
            x.append(my_df.iloc[i]['Latitude'])
            y.append(my_df.iloc[i]['Longitude'])
        d[var1]=x
        d[var2]=y
    return d
#          y.append(my_df[my_df['Bin no.']==i]['Longitude'].values[0])

# %%
def makemap(d):
    from matplotlib.pyplot import figure

    figure(figsize=(8, 6), dpi=80)
    for i in range(int((len(d))/2)):
        var1='y'+str(i)
        var2='x'+str(i)

        plt.plot(d[var1],d[var2])
    
    
    plt.scatter(my_df['Longitude'][1:], my_df['Latitude'][1:], c='g',s=10,label='bin')
    plt.scatter(my_df['Longitude'][0], my_df['Latitude'][0], c='r',marker='s', label='depot')

    plt.legend(loc='upper right');   
    if(int(len(d)/2) == 1):
        plt.title("DLR Refuse Bins for single agent")
    else:
        plt.title("DLR Refuse Bins for mutiple agents")
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.show()

# %%
class AgentSystem():
    def __init__(self):
        self.capacity=0
        self.distance_covered=0
        self.near_nodes=[]
        self.near_node_weight=[]
        self.near_node_dist=[]
        self.curr_node=0
        self.route_list=[0]
        self.agent_id=0
        self.total_dist=[]
        

    def return_depo(self):
        global depo_capacity
        depo_capacity = depo_capacity + self.capacity
        print(f"Distance covered by {self.agent_id} the node is {round(self.distance_covered,2)}")
        
        self.total_dist.append(round(self.distance_covered,2))
        self.capacity=0

        print(f"for {self.agent_id} the route is ")
        print(self.route_list)
        global FINAL_ROUTE, DIST_TOTAL
#         DIST_TOTAL+=self.distance_covered
        try:
            if len(FINAL_ROUTE[self.agent_id]) != 0:
                DIST_TOTAL[self.agent_id] += self.distance_covered
                temp_list=[]
                temp_list=FINAL_ROUTE[self.agent_id] + self.route_list
                FINAL_ROUTE[self.agent_id]=temp_list
        except KeyError:
            FINAL_ROUTE[self.agent_id]=self.route_list
            DIST_TOTAL[self.agent_id]=self.distance_covered
        
        self.distance_covered=0
        self.route_list=[0]
        print("----------------")

    def next_stop(self, next_node):
        self.route_list.append(next_node)
        
        self.curr_node = next_node
        if self.curr_node != depot_node:
            next_node_cap=self.df[self.df['Node']==next_node]['Weight'].values[0]
            next_node_dist=self.df[self.df['Node']==next_node]['Distance'].values[0]
            if (next_node_dist == float('inf')):
              next_node_dist = 0
            self.distance_covered += next_node_dist
            self.capacity += next_node_cap
            if(self.capacity> truck_cap):

                weight[self.curr_node]= self.capacity - truck_cap
                self.capacity = truck_cap
            
            else: 
                weight[self.curr_node]=0
            
        else:
            self.return_depo()
        
        
    def select_action(self):
        
        min_dist= min(self.df["Distance"])
        near_node=self.df[self.df['Distance']== min_dist]['Node'].values[0]
        near_node_cap=self.df[self.df['Node']==near_node]['Weight'].values[0]
        if (near_node_cap == 0):
            random_node = np.random.choice(self.df['Node'])
            # print(f"{self.df['Node']}")
            # near_node=self.df[self.df['Distance']== min_dist]['Node'].values[0]
            near_node_cap=self.df[self.df['Node']==random_node]['Weight'].values[0]
            near_node=random_node
            # print(f"Randomly chosen node is {near_node}")

        if (self.capacity < truck_cap):
            next_node=near_node
            self.distance_covered +=min_dist
            self.capacity += near_node_cap
            self.next_stop(next_node)
            
        else:
            self.next_stop(depot_node)
            

        
    def update_statespace(self,agent_id):
        self.agent_id=agent_id
        A= distance[self.curr_node][:]
        self.near_nodes=list(np.argsort(A))
        self.near_node_dist=list(distance[self.curr_node][self.near_nodes])
        self.near_node_weight=list(weight[self.near_nodes])
        self.df=pd.DataFrame(list(zip(self.near_nodes,self.near_node_dist,self.near_node_weight)),
                             columns = ['Node','Distance', 'Weight'])
        # self.df = self.df[(self.df['Weight'] > 0)]
        # self.df = self.df.nsmallest(10, 'Distance')
        if self.df.empty:
            print('DataFrame is empty!')
            self.next_stop(depot_node)
            return 1
        else:
            self.select_action()
        return (self.total_dist)

# %%
depo_capacity=0
depot_node=0
bins_left=len(my_df)-1
truck_cap=700
weight = pd.Series(list(my_df['weight']))
FINAL_ROUTE={}
DIST_TOTAL={}
city_waste=sum(my_df['weight'])

# %%
distance_covered=[]
agent=AgentSystem()
while(depo_capacity < 1.4*round(city_waste,2)):
    distance_covered.append(agent.update_statespace(0))
# Out:
# Distance covered by 0 the node is 9.14
# for 0 the route is
# [0, 25, 20, 21, 22, 23, 25, 19, 18, 17, 16, 0]
# ----------------
# Distance covered by 0 the node is 4.41
# for 0 the route is
# [0, 5, 4, 0]
# ----------------
# Distance covered by 0 the node is 16.59
# for 0 the route is
# [0, 21, 19, 3, 2, 21, 14, 15, 21, 9, 8, 6, 7, 11, 10, 1, 3, 0]
# ----------------

# %%
d1=prepPlot(FINAL_ROUTE)
makemap(d1)

# %%
print(distance_covered[1])
plt.plot(distance_covered[1])
plt.scatter(range(0,len(distance_covered[1])),distance_covered[1])
plt.title("Distance Covered in Each route")
plt.xlabel("Route number")
plt.ylabel("Distance Covered")
plt.xticks(range(0,1,2))
plt.show
# Out:
# [9.14, 4.41, 16.59]
# <function matplotlib.pyplot.show>

# %%
for key in DIST_TOTAL:
    print(f"The time taken for agent {key} to cover a distance of {round(DIST_TOTAL[key],2)} km is {round(DIST_TOTAL[key]/18.1,2)} hours")
# Out:
# The time taken for agent 0 to cover a distance of 30.13 km is 1.66 hours

# %%
depo_capacity=0
depot_node=0
bins_left=len(my_df)-1
truck_cap=700
weight = pd.Series(list(my_df['weight']))
FINAL_ROUTE={}
# DIST_TOTAL=0
DIST_TOTAL={}

# %%
for x in range(0, 9):
    globals()['Agent%s' % x] = AgentSystem()

while(depo_capacity < 1.4*round(city_waste,2)):

    Agent0.update_statespace(0)
    Agent1.update_statespace(1)
# Out:
# Distance covered by 1 the node is 15.62
# for 1 the route is
# [0, 17, 16, 21, 18, 11, 10, 7, 6, 11, 7, 20, 16, 12, 0]
# ----------------
# Distance covered by 1 the node is 15.71
# for 1 the route is
# [0, 25, 8, 12, 9, 13, 23, 18, 16, 18, 15, 18, 21, 21, 22, 23, 0]
# ----------------
# Distance covered by 0 the node is 40.69
# for 0 the route is
# [0, 25, 20, 21, 22, 23, 21, 3, 2, 9, 8, 5, 4, 3, 9, 6, 8, 13, 14, 15, 20, 3, 17, 19, 22, 21, 13, 14, 6, 20, 24, 10, 23, 5, 15, 19, 18, 6, 6, 17, 1, 10, 2, 16, 19, 0]
# ----------------

# %%
for key in DIST_TOTAL:
    print(f"The time taken for agent {key} to cover a distance of {round(DIST_TOTAL[key],2)} km is {round(DIST_TOTAL[key]*60/18.1,2)} minutes")
# Out:
# The time taken for agent 1 to cover a distance of 31.33 km is 103.85 minutes
# The time taken for agent 0 to cover a distance of 40.69 km is 134.88 minutes

# %%
# AVERAGE_PER_AGENT=round(sum(DIST_TOTAL.values())*60/(len(DIST_TOTAL.keys())*18.1),2)
# print(f"\n\nThe average time taken for each agent to go across its path is {AVERAGE_PER_AGENT} minutes")
AVERAGE_PER_AGENT=round(sum(DIST_TOTAL.values())*60/(len(DIST_TOTAL.keys())*18.1),2)
print(f"\n\nThe average time taken for each agent to go across its path is {AVERAGE_PER_AGENT/60} hours and average distance is {round(sum(DIST_TOTAL.values())/len(DIST_TOTAL.values()),2)} km")
# Out:
# The average time taken for each agent to go across its path is 1.9895 hours and average distance is 36.01 km

# %%
d=prepPlot(FINAL_ROUTE)

# d['x0']=[]
# d['y0']=[]
makemap(d)

# %%
# DIST_TOTAL.values()
plt.bar(DIST_TOTAL.keys(),DIST_TOTAL.values())
# plt.plot(DIST_TOTAL.values())
plt.xticks([0,1])
# plt.yticks([0,20,40,60,80,100,120])
# plt.ylim(50, 120)
plt.title("Distance Covered By Each Agent in a Multi-agent System")
plt.xlabel("Agent number")
plt.ylabel("Distance Covered")
# Out:
# Text(0, 0.5, 'Distance Covered')

# %%
depo_capacity=0
DEPOT_NODE=0
bins_left=len(my_df)-1
TRUCK_CAP=700
ITERATION_NUMBER=0
weight = pd.Series(list(my_df['weight']))
DF_LEN = len(distance)

# %%
class Environment():
    def __init__(self,curr_node=DEPOT_NODE):
        self.curr_node=0
        self.isEnd = False 
        self.StateSpace = pd.DataFrame()
        self.weight=pd.Series(list(my_df['weight']))
        self.distance=distance
        self.prev_node=0
        
    def getReward(self,node,capacity,distance_covered):
        if self.curr_node == DEPOT_NODE:
            if capacity >= 0.9*TRUCK_CAP:
                return 20
            elif sum(self.weight) < 0.00001: # to avoid issues with floating point comparison
                return 10
            else:
                return -50
        else:
            if capacity == self.prev_capacity or self.curr_node == self.prev_node:
                temp_reward=-10
            else:
                temp_reward=0
            return (capacity*10 + (distance_covered * 10)+ temp_reward)

    def isEndFunc(self,capacity):
        if (sum(self.weight)==0):
        # if (self.curr_node == DEPOT_NODE and (capacity >= TRUCK_CAP or sum(self.weight)== 0)):
            print(f"Unloading {capacity} kg of waste at depot")
            self.isEnd = True



    def update_statespace(self, new_node):   #,agent_id):
        A= self.distance[new_node][:]
        self.near_nodes=list(np.argsort(A))
        self.near_node_dist=list(self.distance[new_node][self.near_nodes])
        self.near_node_weight=list(self.weight[self.near_nodes])
        self.StateSpace=pd.DataFrame(list(zip(self.near_nodes,self.near_node_dist,self.near_node_weight)),
                             columns = ['Node','Distance', 'Weight'])

        if self.StateSpace.empty:
            print('DataFrame is empty!')
        return (self.StateSpace)   
    
    def next_position(self,node,action,capacity):   # To add update weight  
        StateSpace=self.update_statespace(node)
        dist=0
        if action in range(1,LEN) :
            self.prev_node = node
            self.curr_node = StateSpace['Node'].iloc[action]
            self.prev_capacity=capacity
            capacity += StateSpace[StateSpace['Node']==self.curr_node]['Weight'].values[0]
            self.weight[self.curr_node]=0
            dist = StateSpace[StateSpace['Node']==self.curr_node]['Distance'].values[0]
                
        elif action == 0 :
            self.curr_node = DEPOT_NODE
            capacity=0
            dist=StateSpace[StateSpace['Node']==DEPOT_NODE]['Distance'].values[0]
            self.isEndFunc(capacity)
        else:
            print(f"In error state Value of action is {action}")
        StateSpace = self.update_statespace(self.curr_node)
        if (dist == float('inf')):
              dist=0
        return self.curr_node,capacity,dist

# %%
class AgentRL():
    def __init__(self):

        self.actions = list(range(0,LEN))    
        self.alpha = 0.5
        self.gamma = 0.9
        self.epsilon = 0.5
        self.plot_reward = []
        self.Q = {}
        self.new_Q = {}
        self.reward=0
        
        for i in range(DF_LEN):
            for k in range(len(self.actions)):  # initialising a 398 x 6 matrix
                self.Q[(i,k)] =0
                self.new_Q[(i, k)] = 0
    def ResetParams(self):
        self.route_list=[0]
        self.capacity=0
        self.isEnd=False
        self.distance_covered=0
        self.curr_node=0
      #self.env=Environment()
    def showValues(self):
        for i in range(0, DF_LEN):
            out = '| '
            mx_nxt_value = -10
            for a in self.actions:
                nxt_value = self.Q[(i,a)]
                if nxt_value >= mx_nxt_value:
                    mx_nxt_value = nxt_value
            out += str(mx_nxt_value).ljust(6) + ' | '
#         print(out)

    def plot(self,routelist_len):
        
        plt.plot(routelist_len)
        plt.show()

    def Action(self,env):
        rnd = random.random()
        mx_nxt_reward =-100
        action = None
        if self.capacity >= 0.9* TRUCK_CAP or self.isEnd:
          action = 0
        elif (self.epsilon > rnd) :
            #iterate through actions, find Q  value and choose best 
            for k in self.actions:
                
                i = env.curr_node
                
                nxt_reward = self.Q[(i, k)]
                
                if nxt_reward >= mx_nxt_reward:
                    action = k
                    mx_nxt_reward = nxt_reward
                    # print(f"mx_nxt_reward = {mx_nxt_reward} for i={i} and k={k}")
        else:
            dummylist=self.actions[:]
            dummylist.remove(0)

            action = np.random.choice(dummylist)
  
        self.curr_node,self.capacity,dist = env.next_position(self.curr_node,action,self.capacity)
        self.distance_covered +=dist
        self.route_list.append(self.curr_node)
        global ITERATION_NUMBER
        ITERATION_NUMBER +=1
        # print(f"-------------Iteration is {ITERATION_NUMBER}\n Value of Action is {action}")
        return self.curr_node,action

        
    def Q_Learning(self,env,epsilon,agentId):
        self.epsilon=epsilon
        capacity = self.capacity
        self.agentId=agentId

        env.isEndFunc(self.capacity)
        self.isEnd=env.isEnd
        if (not self.isEnd):
            mx_nxt_value = -10
            next_node, action = self.Action(env)
            i = next_node
            reward = env.getReward(self.curr_node,self.capacity,self.distance_covered)
            self.reward +=reward
            for a in self.actions:
                nxtEnvironmentAction = (next_node, a)
                q_value = (1-self.alpha)*self.Q[(i,action)] + self.alpha*(reward + self.gamma*self.Q[nxtEnvironmentAction])
                if q_value >= mx_nxt_value:
                    mx_nxt_value = q_value
            env.isEndFunc(self.capacity)
            self.isEnd = env.isEnd
            self.new_Q[(i,action)] = round(mx_nxt_value,3)
          # else:

        self.Q = self.new_Q.copy()
        # print(mx_nxt_value)
        # print(f"Distance covered is {self.distance_covered}")
        return self.route_list,self.distance_covered

# %% [markdown]
# **Running Single Agent RL system**

# %%
if __name__ == "__main__":
    episodes=500
    i=0
    
    ag=AgentRL()
    
    ag.ResetParams()
    ag2=AgentRL()
    ag2.ResetParams()
    env=Environment()
    IsEnd=False  
    routelist_len=[]
    distance_cov=[]
    FINAL_ROUTE1={}
    FINAL_2={}
    epsilon=0.8
    DIST_TOTAL={}
    routelist={}
    routelist0={}
    routelist1={}
    dist2_cov=[]
    while (i<episodes):
        epsilon = 0.95*epsilon
        print(f"-------------{i}--------------")
        IsEnd=False  
        env=Environment()
        ag.ResetParams()
        ag2.ResetParams()
        env.weight=pd.Series(list(my_df['weight']))
        while (int (sum(env.weight))>0):
            routelist0[i],distance_covered=ag.Q_Learning(env,epsilon,0)
            # routelist1[i],dist2_covd=ag2.Q_Learning(env,epsilon,1)
        
        distance_cov.append(distance_covered)
        # dist2_cov.append(dist2_covd)
        routelist_len.append(len(routelist0[0]))
        i +=1
    min_route=routelist_len.index(min(routelist_len))
    routelist[0]=routelist0[min_route]
    # routelist[1]=routelist1[min_route]
    plt.plot(distance_cov)
    # plt.plot(dist2_cov)
    # plt.ylim(0,500)
    # ag.plot(routelist_len)
    # ag.showValues
# Out:
# -------------0--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------1--------------
# Unloading 431.6 kg of waste at depot
# -------------2--------------
# Unloading 431.6 kg of waste at depot
# -------------3--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------4--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------5--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------6--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------7--------------
# Unloading 431.6 kg of waste at depot
# -------------8--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------9--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------10--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------11--------------
# Unloading 431.6 kg of waste at depot
# -------------12--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------13--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------14--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------15--------------
# Unloading 431.6 kg of waste at depot
# -------------16--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------17--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------18--------------
# Unloading 431.6 kg of waste at depot
# -------------19--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------20--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------21--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------22--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------23--------------
# Unloading 431.6 kg of waste at depot
# -------------24--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------25--------------
# Unloading 431.6 kg of waste at depot
# -------------26--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------27--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------28--------------
# Unloading 431.6 kg of waste at depot
# -------------29--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------30--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------31--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------32--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------33--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------34--------------
# Unloading 431.6 kg of waste at depot
# -------------35--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------36--------------
# Unloading 431.6 kg of waste at depot
# -------------37--------------
# Unloading 431.6 kg of waste at depot
# -------------38--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------39--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------40--------------
# Unloading 431.6 kg of waste at depot
# -------------41--------------
# Unloading 431.6 kg of waste at depot
# -------------42--------------
# Unloading 431.6 kg of waste at depot
# -------------43--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------44--------------
# Unloading 431.6 kg of waste at depot
# -------------45--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------46--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------47--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------48--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------49--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------50--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------51--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------52--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------53--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------54--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------55--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------56--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------57--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------58--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------59--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------60--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------61--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------62--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------63--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------64--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------65--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------66--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------67--------------
# Unloading 431.6 kg of waste at depot
# -------------68--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------69--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------70--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------71--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------72--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------73--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------74--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------75--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------76--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------77--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------78--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------79--------------
# Unloading 431.6 kg of waste at depot
# -------------80--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------81--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------82--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------83--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------84--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------85--------------
# Unloading 431.6 kg of waste at depot
# -------------86--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------87--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------88--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------89--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------90--------------
# Unloading 431.6 kg of waste at depot
# -------------91--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------92--------------
# Unloading 431.6 kg of waste at depot
# -------------93--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------94--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------95--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------96--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------97--------------
# Unloading 431.6 kg of waste at depot
# -------------98--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------99--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------100--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------101--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------102--------------
# Unloading 431.6 kg of waste at depot
# -------------103--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------104--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------105--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------106--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------107--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------108--------------
# Unloading 431.6 kg of waste at depot
# -------------109--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------110--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------111--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------112--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------113--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------114--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------115--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------116--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------117--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------118--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------119--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------120--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------121--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------122--------------
# Unloading 431.6 kg of waste at depot
# -------------123--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------124--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------125--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------126--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------127--------------
# Unloading 431.6 kg of waste at depot
# -------------128--------------
# Unloading 431.6 kg of waste at depot
# -------------129--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------130--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------131--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------132--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------133--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------134--------------
# Unloading 431.6 kg of waste at depot
# -------------135--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------136--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------137--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------138--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------139--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------140--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------141--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------142--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------143--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------144--------------
# Unloading 431.6 kg of waste at depot
# -------------145--------------
# Unloading 431.6 kg of waste at depot
# -------------146--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------147--------------
# Unloading 431.6 kg of waste at depot
# -------------148--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------149--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------150--------------
# Unloading 431.6 kg of waste at depot
# -------------151--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------152--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------153--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------154--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------155--------------
# Unloading 431.6 kg of waste at depot
# -------------156--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------157--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------158--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------159--------------
# Unloading 431.6 kg of waste at depot
# -------------160--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------161--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------162--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------163--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------164--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------165--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------166--------------
# Unloading 431.6 kg of waste at depot
# -------------167--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------168--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------169--------------
# Unloading 431.6 kg of waste at depot
# -------------170--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------171--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------172--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------173--------------
# Unloading 431.6 kg of waste at depot
# -------------174--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------175--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------176--------------
# Unloading 431.6 kg of waste at depot
# -------------177--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------178--------------
# Unloading 431.6 kg of waste at depot
# -------------179--------------
# Unloading 431.6 kg of waste at depot
# -------------180--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------181--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------182--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------183--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------184--------------
# Unloading 431.6 kg of waste at depot
# -------------185--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------186--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------187--------------
# Unloading 431.6 kg of waste at depot
# -------------188--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------189--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------190--------------
# Unloading 431.6 kg of waste at depot
# -------------191--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------192--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------193--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------194--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------195--------------
# Unloading 431.6 kg of waste at depot
# -------------196--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------197--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------198--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------199--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------200--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------201--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------202--------------
# Unloading 431.6 kg of waste at depot
# -------------203--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------204--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------205--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------206--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------207--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------208--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------209--------------
# Unloading 431.6 kg of waste at depot
# -------------210--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------211--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------212--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------213--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------214--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------215--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------216--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------217--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------218--------------
# Unloading 431.6 kg of waste at depot
# -------------219--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------220--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------221--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------222--------------
# Unloading 431.6 kg of waste at depot
# -------------223--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------224--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------225--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------226--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------227--------------
# Unloading 431.6 kg of waste at depot
# -------------228--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------229--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------230--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------231--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------232--------------
# Unloading 431.6 kg of waste at depot
# -------------233--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------234--------------
# Unloading 431.6 kg of waste at depot
# -------------235--------------
# Unloading 431.6 kg of waste at depot
# -------------236--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------237--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------238--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------239--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------240--------------
# Unloading 431.6 kg of waste at depot
# -------------241--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------242--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------243--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------244--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------245--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------246--------------
# Unloading 431.6 kg of waste at depot
# -------------247--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------248--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------249--------------
# Unloading 431.6 kg of waste at depot
# -------------250--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------251--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------252--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------253--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------254--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------255--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------256--------------
# Unloading 431.6 kg of waste at depot
# -------------257--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------258--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------259--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------260--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------261--------------
# Unloading 431.6 kg of waste at depot
# -------------262--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------263--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------264--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------265--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------266--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------267--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------268--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------269--------------
# Unloading 431.6 kg of waste at depot
# -------------270--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------271--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------272--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------273--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------274--------------
# Unloading 431.6 kg of waste at depot
# -------------275--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------276--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------277--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------278--------------
# Unloading 431.6 kg of waste at depot
# -------------279--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------280--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------281--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------282--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------283--------------
# Unloading 431.6 kg of waste at depot
# -------------284--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------285--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------286--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------287--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------288--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------289--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------290--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------291--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------292--------------
# Unloading 431.6 kg of waste at depot
# -------------293--------------
# Unloading 431.6 kg of waste at depot
# -------------294--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------295--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------296--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------297--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------298--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------299--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------300--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------301--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------302--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------303--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------304--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------305--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------306--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------307--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------308--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------309--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------310--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------311--------------
# Unloading 431.6 kg of waste at depot
# -------------312--------------
# Unloading 431.6 kg of waste at depot
# -------------313--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------314--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------315--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------316--------------
# Unloading 431.6 kg of waste at depot
# -------------317--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------318--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------319--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------320--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------321--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------322--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------323--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------324--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------325--------------
# Unloading 431.6 kg of waste at depot
# -------------326--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------327--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------328--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------329--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------330--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------331--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------332--------------
# Unloading 431.6 kg of waste at depot
# -------------333--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------334--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------335--------------
# Unloading 431.6 kg of waste at depot
# -------------336--------------
# Unloading 431.6 kg of waste at depot
# -------------337--------------
# Unloading 431.6 kg of waste at depot
# -------------338--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------339--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------340--------------
# Unloading 431.6 kg of waste at depot
# -------------341--------------
# Unloading 431.6 kg of waste at depot
# -------------342--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------343--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------344--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------345--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------346--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------347--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------348--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------349--------------
# Unloading 431.6 kg of waste at depot
# -------------350--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------351--------------
# Unloading 431.6 kg of waste at depot
# -------------352--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------353--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------354--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------355--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------356--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------357--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------358--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------359--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------360--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------361--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------362--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------363--------------
# Unloading 431.6 kg of waste at depot
# -------------364--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------365--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------366--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------367--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------368--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------369--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------370--------------
# Unloading 431.6 kg of waste at depot
# -------------371--------------
# Unloading 431.6 kg of waste at depot
# -------------372--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------373--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------374--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------375--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------376--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------377--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------378--------------
# Unloading 431.6 kg of waste at depot
# -------------379--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------380--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------381--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------382--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------383--------------
# Unloading 431.6 kg of waste at depot
# -------------384--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------385--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------386--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------387--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------388--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------389--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------390--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------391--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------392--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------393--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------394--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------395--------------
# Unloading 431.6 kg of waste at depot
# -------------396--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------397--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------398--------------
# Unloading 431.6 kg of waste at depot
# -------------399--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------400--------------
# Unloading 431.60000000000014 kg of waste at depot
# -------------401--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------402--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------403--------------
# Unloading 431.6 kg of waste at depot
# -------------404--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------405--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------406--------------
# Unloading 431.6 kg of waste at depot
# -------------407--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------408--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------409--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------410--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------411--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------412--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------413--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------414--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------415--------------
# Unloading 431.6 kg of waste at depot
# -------------416--------------
# Unloading 431.6000000000001 kg of waste at depot
# -------------417--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------418--------------
# Unloading 431.6 kg of waste at depot
# -------------419--------------
# Unloading 431.6 kg of waste at depot
# -------------420--------------
# Unloading 431.6 kg of waste at depot
# -------------421--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------422--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------423--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------424--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------425--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------426--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------427--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------428--------------
# Unloading 431.6 kg of waste at depot
# -------------429--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------430--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------431--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------432--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------433--------------
# Unloading 431.6 kg of waste at depot
# -------------434--------------
# Unloading 431.6 kg of waste at depot
# -------------435--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------436--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------437--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------438--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------439--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------440--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------441--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------442--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------443--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------444--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------445--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------446--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------447--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------448--------------
# Unloading 431.6 kg of waste at depot
# -------------449--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------450--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------451--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------452--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------453--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------454--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------455--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------456--------------
# Unloading 431.6 kg of waste at depot
# -------------457--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------458--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------459--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------460--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------461--------------
# Unloading 431.6 kg of waste at depot
# -------------462--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------463--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------464--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------465--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------466--------------
# Unloading 431.6 kg of waste at depot
# -------------467--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------468--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------469--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------470--------------
# Unloading 431.6 kg of waste at depot
# -------------471--------------
# Unloading 431.6 kg of waste at depot
# -------------472--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------473--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------474--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------475--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------476--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------477--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------478--------------
# Unloading 431.6 kg of waste at depot
# -------------479--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------480--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------481--------------
# Unloading 431.6 kg of waste at depot
# -------------482--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------483--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------484--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------485--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------486--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------487--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------488--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------489--------------
# Unloading 431.6 kg of waste at depot
# -------------490--------------
# Unloading 431.6 kg of waste at depot
# -------------491--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------492--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------493--------------
# Unloading 431.59999999999997 kg of waste at depot
# -------------494--------------
# Unloading 431.6 kg of waste at depot
# -------------495--------------
# Unloading 431.59999999999985 kg of waste at depot
# -------------496--------------
# Unloading 431.6 kg of waste at depot
# -------------497--------------
# Unloading 431.5999999999999 kg of waste at depot
# -------------498--------------
# Unloading 431.6 kg of waste at depot
# -------------499--------------
# Unloading 431.59999999999997 kg of waste at depot

# %%
d1=prepPlot(routelist)
d1.keys()
# d3=prepPlot(routelist)
# d3.keys()
# Out:
# dict_keys(['x0', 'y0'])

# %%
makemap(d1)

# %%
print(f"Minimum distance learnt by a Agent in a Reinforcement learning environment is {min(distance_cov)} km ")
# Out:
# Minimum distance learnt by a Agent in a Reinforcement learning environment is 49.0721 km

# %% [markdown]
# **Running Multi-agent RL system**

# %%
if __name__ == "__main__":
    episodes=500
    i=0
    
    ag=AgentRL()
    
    ag.ResetParams()
    ag2=AgentRL()
    ag2.ResetParams()
    env=Environment()
    IsEnd=False  

    epsilon=0.8
    
    FINAL_1={}
    FINAL_2={}

    DIST_TOTAL={}
    routelist={}
    routelist0={}
    routelist1={}

    routelist_len=[]
    dist0_cov=[]
    dist1_cov=[]
    mean_dist=[]
    while (i<episodes):
        epsilon = 0.95*epsilon
        print(f"-------------{i}--------------")
        IsEnd=False  
        env=Environment()
        ag.ResetParams()
        ag2.ResetParams()
        env.weight=pd.Series(list(my_df['weight']))
        while (int (sum(env.weight))>0):
            routelist0[i],dist0_covered=ag.Q_Learning(env,epsilon,0)
            routelist1[i],dist1_covered=ag2.Q_Learning(env,epsilon,1)
        
        meandist=(dist0_covered+dist1_covered)/2
        dist0_cov.append(dist0_covered)
        dist1_cov.append(dist1_covered)
        mean_dist.append(meandist)
        routelist_len.append(len(routelist0[0]))
        i +=1
    min_route=routelist_len.index(min(routelist_len))
    routelist[0]=routelist0[min_route]
    routelist[1]=routelist1[min_route]
    plt.plot(dist0_cov)
    plt.plot(dist1_cov)
    plt.plot(mean_dist)
# Out:
# -------------0--------------
# Unloading 272.7 kg of waste at depot
# Unloading 158.9 kg of waste at depot
# -------------1--------------
# Unloading 217.2 kg of waste at depot
# -------------2--------------
# Unloading 195.0 kg of waste at depot
# -------------3--------------
# Unloading 271.4 kg of waste at depot
# Unloading 160.2 kg of waste at depot
# -------------4--------------
# Unloading 183.8 kg of waste at depot
# -------------5--------------
# Unloading 135.0 kg of waste at depot
# -------------6--------------
# Unloading 186.3 kg of waste at depot
# -------------7--------------
# Unloading 263.9 kg of waste at depot
# -------------8--------------
# Unloading 189.70000000000002 kg of waste at depot
# -------------9--------------
# Unloading 244.7 kg of waste at depot
# Unloading 186.9 kg of waste at depot
# -------------10--------------
# Unloading 197.1 kg of waste at depot
# Unloading 234.49999999999997 kg of waste at depot
# -------------11--------------
# Unloading 205.89999999999998 kg of waste at depot
# Unloading 225.70000000000002 kg of waste at depot
# -------------12--------------
# Unloading 136.5 kg of waste at depot
# -------------13--------------
# Unloading 129.8 kg of waste at depot
# -------------14--------------
# Unloading 201.49999999999997 kg of waste at depot
# -------------15--------------
# Unloading 207.50000000000003 kg of waste at depot
# -------------16--------------
# Unloading 153.9 kg of waste at depot
# -------------17--------------
# Unloading 217.8 kg of waste at depot
# -------------18--------------
# Unloading 221.29999999999998 kg of waste at depot
# Unloading 210.3 kg of waste at depot
# -------------19--------------
# Unloading 217.0 kg of waste at depot
# -------------20--------------
# Unloading 230.4 kg of waste at depot
# Unloading 201.2 kg of waste at depot
# -------------21--------------
# Unloading 205.1 kg of waste at depot
# -------------22--------------
# Unloading 149.7 kg of waste at depot
# -------------23--------------
# Unloading 233.3 kg of waste at depot
# Unloading 198.3 kg of waste at depot
# -------------24--------------
# Unloading 188.3 kg of waste at depot
# -------------25--------------
# Unloading 212.89999999999998 kg of waste at depot
# -------------26--------------
# Unloading 273.2 kg of waste at depot
# -------------27--------------
# Unloading 188.6 kg of waste at depot
# Unloading 243.0 kg of waste at depot
# -------------28--------------
# Unloading 256.2 kg of waste at depot
# -------------29--------------
# Unloading 298.3 kg of waste at depot
# -------------30--------------
# Unloading 253.20000000000002 kg of waste at depot
# -------------31--------------
# Unloading 167.20000000000002 kg of waste at depot
# -------------32--------------
# Unloading 192.5 kg of waste at depot
# -------------33--------------
# Unloading 251.2 kg of waste at depot
# -------------34--------------
# Unloading 235.00000000000003 kg of waste at depot
# Unloading 196.6 kg of waste at depot
# -------------35--------------
# Unloading 250.89999999999998 kg of waste at depot
# -------------36--------------
# Unloading 143.4 kg of waste at depot
# -------------37--------------
# Unloading 302.70000000000005 kg of waste at depot
# Unloading 128.9 kg of waste at depot
# -------------38--------------
# Unloading 263.3 kg of waste at depot
# Unloading 168.3 kg of waste at depot
# -------------39--------------
# Unloading 213.6 kg of waste at depot
# Unloading 218.00000000000003 kg of waste at depot
# -------------40--------------
# Unloading 277.9 kg of waste at depot
# Unloading 153.7 kg of waste at depot
# -------------41--------------
# Unloading 250.5 kg of waste at depot
# -------------42--------------
# Unloading 199.20000000000002 kg of waste at depot
# Unloading 232.4 kg of waste at depot
# -------------43--------------
# Unloading 202.4 kg of waste at depot
# Unloading 229.2 kg of waste at depot
# -------------44--------------
# Unloading 266.1 kg of waste at depot
# -------------45--------------
# Unloading 208.3 kg of waste at depot
# Unloading 223.29999999999998 kg of waste at depot
# -------------46--------------
# Unloading 239.09999999999997 kg of waste at depot
# -------------47--------------
# Unloading 176.7 kg of waste at depot
# -------------48--------------
# Unloading 266.4 kg of waste at depot
# -------------49--------------
# Unloading 193.0 kg of waste at depot
# -------------50--------------
# Unloading 148.10000000000002 kg of waste at depot
# Unloading 283.5 kg of waste at depot
# -------------51--------------
# Unloading 165.9 kg of waste at depot
# Unloading 265.7 kg of waste at depot
# -------------52--------------
# Unloading 189.5 kg of waste at depot
# Unloading 242.10000000000002 kg of waste at depot
# -------------53--------------
# Unloading 174.3 kg of waste at depot
# -------------54--------------
# Unloading 269.29999999999995 kg of waste at depot
# -------------55--------------
# Unloading 197.2 kg of waste at depot
# -------------56--------------
# Unloading 180.4 kg of waste at depot
# -------------57--------------
# Unloading 163.1 kg of waste at depot
# -------------58--------------
# Unloading 268.8 kg of waste at depot
# -------------59--------------
# Unloading 231.20000000000002 kg of waste at depot
# Unloading 200.4 kg of waste at depot
# -------------60--------------
# Unloading 219.29999999999998 kg of waste at depot
# -------------61--------------
# Unloading 268.79999999999995 kg of waste at depot
# Unloading 162.79999999999998 kg of waste at depot
# -------------62--------------
# Unloading 206.99999999999997 kg of waste at depot
# Unloading 224.60000000000002 kg of waste at depot
# -------------63--------------
# Unloading 228.5 kg of waste at depot
# Unloading 203.10000000000002 kg of waste at depot
# -------------64--------------
# Unloading 255.4 kg of waste at depot
# -------------65--------------
# Unloading 219.9 kg of waste at depot
# -------------66--------------
# Unloading 270.7 kg of waste at depot
# Unloading 160.9 kg of waste at depot
# -------------67--------------
# Unloading 231.3 kg of waste at depot
# -------------68--------------
# Unloading 233.8 kg of waste at depot
# Unloading 197.8 kg of waste at depot
# -------------69--------------
# Unloading 236.6 kg of waste at depot
# Unloading 195.0 kg of waste at depot
# -------------70--------------
# Unloading 197.3 kg of waste at depot
# Unloading 234.3 kg of waste at depot
# -------------71--------------
# Unloading 238.2 kg of waste at depot
# -------------72--------------
# Unloading 245.29999999999998 kg of waste at depot
# Unloading 186.29999999999998 kg of waste at depot
# -------------73--------------
# Unloading 189.6 kg of waste at depot
# Unloading 242.0 kg of waste at depot
# -------------74--------------
# Unloading 263.79999999999995 kg of waste at depot
# -------------75--------------
# Unloading 209.6 kg of waste at depot
# Unloading 222.0 kg of waste at depot
# -------------76--------------
# Unloading 202.79999999999998 kg of waste at depot
# -------------77--------------
# Unloading 188.7 kg of waste at depot
# Unloading 242.9 kg of waste at depot
# -------------78--------------
# Unloading 174.20000000000002 kg of waste at depot
# -------------79--------------
# Unloading 169.8 kg of waste at depot
# -------------80--------------
# Unloading 238.49999999999997 kg of waste at depot
# Unloading 193.1 kg of waste at depot
# -------------81--------------
# Unloading 178.9 kg of waste at depot
# -------------82--------------
# Unloading 191.9 kg of waste at depot
# -------------83--------------
# Unloading 237.8 kg of waste at depot
# Unloading 193.79999999999998 kg of waste at depot
# -------------84--------------
# Unloading 207.1 kg of waste at depot
# -------------85--------------
# Unloading 268.4 kg of waste at depot
# Unloading 163.2 kg of waste at depot
# -------------86--------------
# Unloading 215.1 kg of waste at depot
# Unloading 216.5 kg of waste at depot
# -------------87--------------
# Unloading 172.4 kg of waste at depot
# Unloading 259.20000000000005 kg of waste at depot
# -------------88--------------
# Unloading 211.39999999999998 kg of waste at depot
# -------------89--------------
# Unloading 235.2 kg of waste at depot
# Unloading 196.4 kg of waste at depot
# -------------90--------------
# Unloading 219.00000000000003 kg of waste at depot
# -------------91--------------
# Unloading 267.6 kg of waste at depot
# -------------92--------------
# Unloading 225.50000000000003 kg of waste at depot
# -------------93--------------
# Unloading 297.8999999999999 kg of waste at depot
# Unloading 133.7 kg of waste at depot
# -------------94--------------
# Unloading 213.2 kg of waste at depot
# -------------95--------------
# Unloading 154.9 kg of waste at depot
# Unloading 276.70000000000005 kg of waste at depot
# -------------96--------------
# Unloading 234.7 kg of waste at depot
# Unloading 196.9 kg of waste at depot
# -------------97--------------
# Unloading 232.7 kg of waste at depot
# -------------98--------------
# Unloading 137.0 kg of waste at depot
# -------------99--------------
# Unloading 264.8 kg of waste at depot
# Unloading 166.8 kg of waste at depot
# -------------100--------------
# Unloading 230.79999999999998 kg of waste at depot
# -------------101--------------
# Unloading 264.0 kg of waste at depot
# Unloading 167.6 kg of waste at depot
# -------------102--------------
# Unloading 179.5 kg of waste at depot
# Unloading 252.10000000000002 kg of waste at depot
# -------------103--------------
# Unloading 218.79999999999998 kg of waste at depot
# -------------104--------------
# Unloading 201.6 kg of waste at depot
# Unloading 230.0 kg of waste at depot
# -------------105--------------
# Unloading 209.79999999999998 kg of waste at depot
# Unloading 221.79999999999998 kg of waste at depot
# -------------106--------------
# Unloading 234.7 kg of waste at depot
# Unloading 196.90000000000003 kg of waste at depot
# -------------107--------------
# Unloading 142.4 kg of waste at depot
# -------------108--------------
# Unloading 208.40000000000003 kg of waste at depot
# Unloading 223.2 kg of waste at depot
# -------------109--------------
# Unloading 257.0 kg of waste at depot
# Unloading 174.60000000000002 kg of waste at depot
# -------------110--------------
# Unloading 256.9 kg of waste at depot
# -------------111--------------
# Unloading 234.20000000000002 kg of waste at depot
# -------------112--------------
# Unloading 299.80000000000007 kg of waste at depot
# Unloading 131.79999999999998 kg of waste at depot
# -------------113--------------
# Unloading 228.8 kg of waste at depot
# Unloading 202.8 kg of waste at depot
# -------------114--------------
# Unloading 244.2 kg of waste at depot
# -------------115--------------
# Unloading 291.0 kg of waste at depot
# -------------116--------------
# Unloading 277.7 kg of waste at depot
# Unloading 153.9 kg of waste at depot
# -------------117--------------
# Unloading 262.4 kg of waste at depot
# Unloading 169.2 kg of waste at depot
# -------------118--------------
# Unloading 198.3 kg of waste at depot
# -------------119--------------
# Unloading 215.6 kg of waste at depot
# Unloading 216.0 kg of waste at depot
# -------------120--------------
# Unloading 220.99999999999997 kg of waste at depot
# -------------121--------------
# Unloading 230.6 kg of waste at depot
# Unloading 201.0 kg of waste at depot
# -------------122--------------
# Unloading 195.70000000000002 kg of waste at depot
# Unloading 235.9 kg of waste at depot
# -------------123--------------
# Unloading 242.29999999999998 kg of waste at depot
# -------------124--------------
# Unloading 268.70000000000005 kg of waste at depot
# Unloading 162.9 kg of waste at depot
# -------------125--------------
# Unloading 184.7 kg of waste at depot
# Unloading 246.9 kg of waste at depot
# -------------126--------------
# Unloading 167.7 kg of waste at depot
# -------------127--------------
# Unloading 195.4 kg of waste at depot
# Unloading 236.20000000000002 kg of waste at depot
# -------------128--------------
# Unloading 284.3 kg of waste at depot
# Unloading 147.3 kg of waste at depot
# -------------129--------------
# Unloading 235.9 kg of waste at depot
# -------------130--------------
# Unloading 173.9 kg of waste at depot
# -------------131--------------
# Unloading 147.8 kg of waste at depot
# Unloading 283.8 kg of waste at depot
# -------------132--------------
# Unloading 208.6 kg of waste at depot
# -------------133--------------
# Unloading 274.79999999999995 kg of waste at depot
# -------------134--------------
# Unloading 180.0 kg of waste at depot
# Unloading 251.6 kg of waste at depot
# -------------135--------------
# Unloading 202.4 kg of waste at depot
# Unloading 229.20000000000002 kg of waste at depot
# -------------136--------------
# Unloading 198.4 kg of waste at depot
# Unloading 233.20000000000002 kg of waste at depot
# -------------137--------------
# Unloading 162.4 kg of waste at depot
# -------------138--------------
# Unloading 232.1 kg of waste at depot
# Unloading 199.5 kg of waste at depot
# -------------139--------------
# Unloading 248.6 kg of waste at depot
# -------------140--------------
# Unloading 296.9 kg of waste at depot
# Unloading 134.70000000000002 kg of waste at depot
# -------------141--------------
# Unloading 194.49999999999997 kg of waste at depot
# -------------142--------------
# Unloading 175.1 kg of waste at depot
# -------------143--------------
# Unloading 250.49999999999997 kg of waste at depot
# -------------144--------------
# Unloading 227.4 kg of waste at depot
# -------------145--------------
# Unloading 201.3 kg of waste at depot
# -------------146--------------
# Unloading 211.1 kg of waste at depot
# -------------147--------------
# Unloading 198.20000000000005 kg of waste at depot
# -------------148--------------
# Unloading 300.8 kg of waste at depot
# -------------149--------------
# Unloading 292.2 kg of waste at depot
# Unloading 139.4 kg of waste at depot
# -------------150--------------
# Unloading 277.7 kg of waste at depot
# Unloading 153.89999999999998 kg of waste at depot
# -------------151--------------
# Unloading 285.70000000000005 kg of waste at depot
# Unloading 145.9 kg of waste at depot
# -------------152--------------
# Unloading 244.70000000000002 kg of waste at depot
# -------------153--------------
# Unloading 243.4 kg of waste at depot
# -------------154--------------
# Unloading 290.1 kg of waste at depot
# Unloading 141.5 kg of waste at depot
# -------------155--------------
# Unloading 194.7 kg of waste at depot
# -------------156--------------
# Unloading 235.5 kg of waste at depot
# Unloading 196.1 kg of waste at depot
# -------------157--------------
# Unloading 273.1 kg of waste at depot
# -------------158--------------
# Unloading 250.6 kg of waste at depot
# -------------159--------------
# Unloading 187.4 kg of waste at depot
# Unloading 244.2 kg of waste at depot
# -------------160--------------
# Unloading 259.2 kg of waste at depot
# -------------161--------------
# Unloading 237.39999999999998 kg of waste at depot
# -------------162--------------
# Unloading 171.6 kg of waste at depot
# Unloading 259.99999999999994 kg of waste at depot
# -------------163--------------
# Unloading 266.0 kg of waste at depot
# -------------164--------------
# Unloading 200.20000000000005 kg of waste at depot
# Unloading 231.4 kg of waste at depot
# -------------165--------------
# Unloading 293.5 kg of waste at depot
# -------------166--------------
# Unloading 202.3 kg of waste at depot
# -------------167--------------
# Unloading 239.1 kg of waste at depot
# -------------168--------------
# Unloading 161.0 kg of waste at depot
# -------------169--------------
# Unloading 338.09999999999997 kg of waste at depot
# Unloading 93.5 kg of waste at depot
# -------------170--------------
# Unloading 205.79999999999998 kg of waste at depot
# -------------171--------------
# Unloading 219.7 kg of waste at depot
# -------------172--------------
# Unloading 183.7 kg of waste at depot
# -------------173--------------
# Unloading 163.79999999999998 kg of waste at depot
# Unloading 267.8 kg of waste at depot
# -------------174--------------
# Unloading 157.10000000000002 kg of waste at depot
# -------------175--------------
# Unloading 277.2 kg of waste at depot
# -------------176--------------
# Unloading 239.60000000000002 kg of waste at depot
# Unloading 192.0 kg of waste at depot
# -------------177--------------
# Unloading 183.4 kg of waste at depot
# -------------178--------------
# Unloading 282.6 kg of waste at depot
# -------------179--------------
# Unloading 224.2 kg of waste at depot
# Unloading 207.4 kg of waste at depot
# -------------180--------------
# Unloading 215.99999999999997 kg of waste at depot
# -------------181--------------
# Unloading 261.7 kg of waste at depot
# -------------182--------------
# Unloading 210.89999999999998 kg of waste at depot
# Unloading 220.7 kg of waste at depot
# -------------183--------------
# Unloading 182.5 kg of waste at depot
# Unloading 249.1 kg of waste at depot
# -------------184--------------
# Unloading 213.39999999999998 kg of waste at depot
# -------------185--------------
# Unloading 231.2 kg of waste at depot
# -------------186--------------
# Unloading 281.2 kg of waste at depot
# Unloading 150.40000000000003 kg of waste at depot
# -------------187--------------
# Unloading 165.60000000000002 kg of waste at depot
# -------------188--------------
# Unloading 181.8 kg of waste at depot
# -------------189--------------
# Unloading 272.20000000000005 kg of waste at depot
# Unloading 159.4 kg of waste at depot
# -------------190--------------
# Unloading 220.7 kg of waste at depot
# -------------191--------------
# Unloading 258.2 kg of waste at depot
# Unloading 173.4 kg of waste at depot
# -------------192--------------
# Unloading 241.6 kg of waste at depot
# -------------193--------------
# Unloading 250.79999999999995 kg of waste at depot
# -------------194--------------
# Unloading 188.39999999999998 kg of waste at depot
# -------------195--------------
# Unloading 193.00000000000003 kg of waste at depot
# Unloading 238.6 kg of waste at depot
# -------------196--------------
# Unloading 198.3 kg of waste at depot
# -------------197--------------
# Unloading 169.20000000000002 kg of waste at depot
# Unloading 262.4 kg of waste at depot
# -------------198--------------
# Unloading 248.9 kg of waste at depot
# Unloading 182.7 kg of waste at depot
# -------------199--------------
# Unloading 275.29999999999995 kg of waste at depot
# Unloading 156.29999999999998 kg of waste at depot
# -------------200--------------
# Unloading 287.59999999999997 kg of waste at depot
# Unloading 144.0 kg of waste at depot
# -------------201--------------
# Unloading 236.39999999999998 kg of waste at depot
# Unloading 195.20000000000002 kg of waste at depot
# -------------202--------------
# Unloading 266.0 kg of waste at depot
# -------------203--------------
# Unloading 287.4 kg of waste at depot
# -------------204--------------
# Unloading 248.7 kg of waste at depot
# Unloading 182.9 kg of waste at depot
# -------------205--------------
# Unloading 182.4 kg of waste at depot
# -------------206--------------
# Unloading 180.1 kg of waste at depot
# -------------207--------------
# Unloading 231.39999999999998 kg of waste at depot
# Unloading 200.2 kg of waste at depot
# -------------208--------------
# Unloading 213.0 kg of waste at depot
# -------------209--------------
# Unloading 250.99999999999997 kg of waste at depot
# -------------210--------------
# Unloading 177.20000000000002 kg of waste at depot
# -------------211--------------
# Unloading 156.2 kg of waste at depot
# Unloading 275.40000000000003 kg of waste at depot
# -------------212--------------
# Unloading 183.2 kg of waste at depot
# -------------213--------------
# Unloading 165.9 kg of waste at depot
# -------------214--------------
# Unloading 192.79999999999998 kg of waste at depot
# -------------215--------------
# Unloading 241.49999999999997 kg of waste at depot
# -------------216--------------
# Unloading 264.3 kg of waste at depot
# Unloading 167.3 kg of waste at depot
# -------------217--------------
# Unloading 213.3 kg of waste at depot
# Unloading 218.3 kg of waste at depot
# -------------218--------------
# Unloading 212.29999999999998 kg of waste at depot
# Unloading 219.30000000000004 kg of waste at depot
# -------------219--------------
# Unloading 153.9 kg of waste at depot
# Unloading 277.7 kg of waste at depot
# -------------220--------------
# Unloading 277.50000000000006 kg of waste at depot
# Unloading 154.1 kg of waste at depot
# -------------221--------------
# Unloading 225.3 kg of waste at depot
# Unloading 206.29999999999995 kg of waste at depot
# -------------222--------------
# Unloading 183.20000000000002 kg of waste at depot
# -------------223--------------
# Unloading 200.20000000000002 kg of waste at depot
# -------------224--------------
# Unloading 211.79999999999998 kg of waste at depot
# Unloading 219.79999999999998 kg of waste at depot
# -------------225--------------
# Unloading 265.09999999999997 kg of waste at depot
# -------------226--------------
# Unloading 277.29999999999995 kg of waste at depot
# -------------227--------------
# Unloading 243.60000000000002 kg of waste at depot
# -------------228--------------
# Unloading 235.39999999999998 kg of waste at depot
# -------------229--------------
# Unloading 205.6 kg of waste at depot
# Unloading 226.0 kg of waste at depot
# -------------230--------------
# Unloading 243.59999999999997 kg of waste at depot
# -------------231--------------
# Unloading 249.20000000000002 kg of waste at depot
# Unloading 182.4 kg of waste at depot
# -------------232--------------
# Unloading 166.1 kg of waste at depot
# Unloading 265.5 kg of waste at depot
# -------------233--------------
# Unloading 193.29999999999998 kg of waste at depot
# -------------234--------------
# Unloading 241.3 kg of waste at depot
# Unloading 190.3 kg of waste at depot
# -------------235--------------
# Unloading 251.3 kg of waste at depot
# Unloading 180.29999999999998 kg of waste at depot
# -------------236--------------
# Unloading 282.2 kg of waste at depot
# -------------237--------------
# Unloading 205.3 kg of waste at depot
# Unloading 226.29999999999998 kg of waste at depot
# -------------238--------------
# Unloading 305.7 kg of waste at depot
# -------------239--------------
# Unloading 252.70000000000002 kg of waste at depot
# Unloading 178.9 kg of waste at depot
# -------------240--------------
# Unloading 212.8 kg of waste at depot
# -------------241--------------
# Unloading 198.1 kg of waste at depot
# Unloading 233.49999999999997 kg of waste at depot
# -------------242--------------
# Unloading 162.8 kg of waste at depot
# -------------243--------------
# Unloading 314.59999999999997 kg of waste at depot
# Unloading 117.0 kg of waste at depot
# -------------244--------------
# Unloading 250.6 kg of waste at depot
# Unloading 181.00000000000003 kg of waste at depot
# -------------245--------------
# Unloading 288.79999999999995 kg of waste at depot
# -------------246--------------
# Unloading 203.4 kg of waste at depot
# Unloading 228.20000000000002 kg of waste at depot
# -------------247--------------
# Unloading 198.5 kg of waste at depot
# -------------248--------------
# Unloading 190.2 kg of waste at depot
# Unloading 241.4 kg of waste at depot
# -------------249--------------
# Unloading 268.49999999999994 kg of waste at depot
# -------------250--------------
# Unloading 246.1 kg of waste at depot
# Unloading 185.5 kg of waste at depot
# -------------251--------------
# Unloading 171.9 kg of waste at depot
# Unloading 259.7 kg of waste at depot
# -------------252--------------
# Unloading 278.5 kg of waste at depot
# -------------253--------------
# Unloading 231.1 kg of waste at depot
# Unloading 200.5 kg of waste at depot
# -------------254--------------
# Unloading 165.6 kg of waste at depot
# -------------255--------------
# Unloading 206.5 kg of waste at depot
# -------------256--------------
# Unloading 179.1 kg of waste at depot
# -------------257--------------
# Unloading 280.8 kg of waste at depot
# -------------258--------------
# Unloading 243.00000000000003 kg of waste at depot
# -------------259--------------
# Unloading 279.8 kg of waste at depot
# Unloading 151.8 kg of waste at depot
# -------------260--------------
# Unloading 292.9 kg of waste at depot
# -------------261--------------
# Unloading 165.4 kg of waste at depot
# Unloading 266.2 kg of waste at depot
# -------------262--------------
# Unloading 227.4 kg of waste at depot
# Unloading 204.2 kg of waste at depot
# -------------263--------------
# Unloading 223.3 kg of waste at depot
# -------------264--------------
# Unloading 234.3 kg of waste at depot
# Unloading 197.30000000000004 kg of waste at depot
# -------------265--------------
# Unloading 229.70000000000002 kg of waste at depot
# -------------266--------------
# Unloading 254.8 kg of waste at depot
# Unloading 176.79999999999998 kg of waste at depot
# -------------267--------------
# Unloading 141.7 kg of waste at depot
# -------------268--------------
# Unloading 259.7 kg of waste at depot
# Unloading 171.9 kg of waste at depot
# -------------269--------------
# Unloading 199.0 kg of waste at depot
# Unloading 232.60000000000002 kg of waste at depot
# -------------270--------------
# Unloading 208.60000000000002 kg of waste at depot
# Unloading 223.0 kg of waste at depot
# -------------271--------------
# Unloading 164.20000000000002 kg of waste at depot
# Unloading 267.4 kg of waste at depot
# -------------272--------------
# Unloading 183.8 kg of waste at depot
# -------------273--------------
# Unloading 180.4 kg of waste at depot
# -------------274--------------
# Unloading 150.8 kg of waste at depot
# -------------275--------------
# Unloading 252.60000000000005 kg of waste at depot
# Unloading 179.0 kg of waste at depot
# -------------276--------------
# Unloading 169.50000000000003 kg of waste at depot
# -------------277--------------
# Unloading 295.40000000000003 kg of waste at depot
# -------------278--------------
# Unloading 210.6 kg of waste at depot
# Unloading 221.0 kg of waste at depot
# -------------279--------------
# Unloading 194.5 kg of waste at depot
# Unloading 237.1 kg of waste at depot
# -------------280--------------
# Unloading 208.20000000000002 kg of waste at depot
# -------------281--------------
# Unloading 187.1 kg of waste at depot
# Unloading 244.5 kg of waste at depot
# -------------282--------------
# Unloading 239.89999999999998 kg of waste at depot
# -------------283--------------
# Unloading 204.79999999999998 kg of waste at depot
# Unloading 226.8 kg of waste at depot
# -------------284--------------
# Unloading 288.0 kg of waste at depot
# Unloading 143.6 kg of waste at depot
# -------------285--------------
# Unloading 203.0 kg of waste at depot
# -------------286--------------
# Unloading 189.7 kg of waste at depot
# -------------287--------------
# Unloading 209.49999999999997 kg of waste at depot
# -------------288--------------
# Unloading 225.60000000000002 kg of waste at depot
# -------------289--------------
# Unloading 173.5 kg of waste at depot
# -------------290--------------
# Unloading 241.4 kg of waste at depot
# -------------291--------------
# Unloading 193.9 kg of waste at depot
# -------------292--------------
# Unloading 232.6 kg of waste at depot
# -------------293--------------
# Unloading 220.79999999999998 kg of waste at depot
# -------------294--------------
# Unloading 175.29999999999998 kg of waste at depot
# Unloading 256.29999999999995 kg of waste at depot
# -------------295--------------
# Unloading 255.2 kg of waste at depot
# Unloading 176.4 kg of waste at depot
# -------------296--------------
# Unloading 184.29999999999998 kg of waste at depot
# -------------297--------------
# Unloading 252.0 kg of waste at depot
# Unloading 179.6 kg of waste at depot
# -------------298--------------
# Unloading 238.4 kg of waste at depot
# Unloading 193.2 kg of waste at depot
# -------------299--------------
# Unloading 147.1 kg of waste at depot
# -------------300--------------
# Unloading 250.5 kg of waste at depot
# Unloading 181.1 kg of waste at depot
# -------------301--------------
# Unloading 270.5 kg of waste at depot
# Unloading 161.1 kg of waste at depot
# -------------302--------------
# Unloading 188.9 kg of waste at depot
# -------------303--------------
# Unloading 246.29999999999998 kg of waste at depot
# Unloading 185.29999999999998 kg of waste at depot
# -------------304--------------
# Unloading 279.6 kg of waste at depot
# -------------305--------------
# Unloading 264.1 kg of waste at depot
# -------------306--------------
# Unloading 278.59999999999997 kg of waste at depot
# Unloading 153.0 kg of waste at depot
# -------------307--------------
# Unloading 221.20000000000002 kg of waste at depot
# -------------308--------------
# Unloading 216.8 kg of waste at depot
# -------------309--------------
# Unloading 239.2 kg of waste at depot
# Unloading 192.39999999999998 kg of waste at depot
# -------------310--------------
# Unloading 229.0 kg of waste at depot
# -------------311--------------
# Unloading 223.6 kg of waste at depot
# Unloading 208.00000000000003 kg of waste at depot
# -------------312--------------
# Unloading 246.8 kg of waste at depot
# -------------313--------------
# Unloading 215.9 kg of waste at depot
# -------------314--------------
# Unloading 183.2 kg of waste at depot
# -------------315--------------
# Unloading 124.89999999999999 kg of waste at depot
# -------------316--------------
# Unloading 252.4 kg of waste at depot
# -------------317--------------
# Unloading 178.0 kg of waste at depot
# Unloading 253.6 kg of waste at depot
# -------------318--------------
# Unloading 215.29999999999998 kg of waste at depot
# Unloading 216.3 kg of waste at depot
# -------------319--------------
# Unloading 248.00000000000003 kg of waste at depot
# Unloading 183.6 kg of waste at depot
# -------------320--------------
# Unloading 251.6 kg of waste at depot
# -------------321--------------
# Unloading 226.0 kg of waste at depot
# Unloading 205.6 kg of waste at depot
# -------------322--------------
# Unloading 236.99999999999997 kg of waste at depot
# Unloading 194.6 kg of waste at depot
# -------------323--------------
# Unloading 251.1 kg of waste at depot
# Unloading 180.5 kg of waste at depot
# -------------324--------------
# Unloading 238.9 kg of waste at depot
# Unloading 192.7 kg of waste at depot
# -------------325--------------
# Unloading 209.9 kg of waste at depot
# Unloading 221.7 kg of waste at depot
# -------------326--------------
# Unloading 175.79999999999998 kg of waste at depot
# -------------327--------------
# Unloading 243.8 kg of waste at depot
# Unloading 187.79999999999998 kg of waste at depot
# -------------328--------------
# Unloading 221.9 kg of waste at depot
# -------------329--------------
# Unloading 218.7 kg of waste at depot
# Unloading 212.9 kg of waste at depot
# -------------330--------------
# Unloading 254.39999999999998 kg of waste at depot
# -------------331--------------
# Unloading 207.9 kg of waste at depot
# -------------332--------------
# Unloading 214.4 kg of waste at depot
# -------------333--------------
# Unloading 311.29999999999995 kg of waste at depot
# Unloading 120.30000000000001 kg of waste at depot
# -------------334--------------
# Unloading 238.29999999999998 kg of waste at depot
# Unloading 193.3 kg of waste at depot
# -------------335--------------
# Unloading 212.8 kg of waste at depot
# -------------336--------------
# Unloading 186.2 kg of waste at depot
# -------------337--------------
# Unloading 275.5 kg of waste at depot
# -------------338--------------
# Unloading 271.7 kg of waste at depot
# -------------339--------------
# Unloading 185.0 kg of waste at depot
# -------------340--------------
# Unloading 263.5 kg of waste at depot
# Unloading 168.1 kg of waste at depot
# -------------341--------------
# Unloading 190.19999999999996 kg of waste at depot
# -------------342--------------
# Unloading 280.09999999999997 kg of waste at depot
# Unloading 151.5 kg of waste at depot
# -------------343--------------
# Unloading 202.4 kg of waste at depot
# Unloading 229.2 kg of waste at depot
# -------------344--------------
# Unloading 144.3 kg of waste at depot
# -------------345--------------
# Unloading 249.10000000000002 kg of waste at depot
# -------------346--------------
# Unloading 200.79999999999998 kg of waste at depot
# Unloading 230.8 kg of waste at depot
# -------------347--------------
# Unloading 107.80000000000001 kg of waste at depot
# -------------348--------------
# Unloading 255.1 kg of waste at depot
# -------------349--------------
# Unloading 313.7 kg of waste at depot
# Unloading 117.9 kg of waste at depot
# -------------350--------------
# Unloading 288.70000000000005 kg of waste at depot
# -------------351--------------
# Unloading 203.3 kg of waste at depot
# -------------352--------------
# Unloading 287.3 kg of waste at depot
# Unloading 144.3 kg of waste at depot
# -------------353--------------
# Unloading 252.10000000000002 kg of waste at depot
# Unloading 179.5 kg of waste at depot
# -------------354--------------
# Unloading 272.8 kg of waste at depot
# -------------355--------------
# Unloading 271.9 kg of waste at depot
# -------------356--------------
# Unloading 248.9 kg of waste at depot
# Unloading 182.70000000000002 kg of waste at depot
# -------------357--------------
# Unloading 255.8 kg of waste at depot
# Unloading 175.8 kg of waste at depot
# -------------358--------------
# Unloading 289.0 kg of waste at depot
# Unloading 142.6 kg of waste at depot
# -------------359--------------
# Unloading 234.8 kg of waste at depot
# -------------360--------------
# Unloading 187.3 kg of waste at depot
# -------------361--------------
# Unloading 254.20000000000002 kg of waste at depot
# -------------362--------------
# Unloading 229.39999999999998 kg of waste at depot
# Unloading 202.2 kg of waste at depot
# -------------363--------------
# Unloading 233.4 kg of waste at depot
# Unloading 198.2 kg of waste at depot
# -------------364--------------
# Unloading 222.7 kg of waste at depot
# Unloading 208.89999999999998 kg of waste at depot
# -------------365--------------
# Unloading 256.3 kg of waste at depot
# -------------366--------------
# Unloading 188.29999999999998 kg of waste at depot
# -------------367--------------
# Unloading 200.1 kg of waste at depot
# -------------368--------------
# Unloading 278.3 kg of waste at depot
# Unloading 153.3 kg of waste at depot
# -------------369--------------
# Unloading 237.49999999999997 kg of waste at depot
# -------------370--------------
# Unloading 192.4 kg of waste at depot
# -------------371--------------
# Unloading 243.7 kg of waste at depot
# -------------372--------------
# Unloading 212.3 kg of waste at depot
# -------------373--------------
# Unloading 214.5 kg of waste at depot
# -------------374--------------
# Unloading 234.20000000000002 kg of waste at depot
# -------------375--------------
# Unloading 251.7 kg of waste at depot
# -------------376--------------
# Unloading 215.90000000000003 kg of waste at depot
# -------------377--------------
# Unloading 223.60000000000002 kg of waste at depot
# Unloading 208.0 kg of waste at depot
# -------------378--------------
# Unloading 278.4 kg of waste at depot
# -------------379--------------
# Unloading 212.6 kg of waste at depot
# Unloading 219.0 kg of waste at depot
# -------------380--------------
# Unloading 282.0 kg of waste at depot
# -------------381--------------
# Unloading 168.10000000000002 kg of waste at depot
# -------------382--------------
# Unloading 247.99999999999997 kg of waste at depot
# Unloading 183.6 kg of waste at depot
# -------------383--------------
# Unloading 261.3 kg of waste at depot
# Unloading 170.29999999999998 kg of waste at depot
# -------------384--------------
# Unloading 258.4 kg of waste at depot
# Unloading 173.20000000000002 kg of waste at depot
# -------------385--------------
# Unloading 297.79999999999995 kg of waste at depot
# -------------386--------------
# Unloading 163.1 kg of waste at depot
# -------------387--------------
# Unloading 234.6 kg of waste at depot
# Unloading 197.0 kg of waste at depot
# -------------388--------------
# Unloading 216.10000000000002 kg of waste at depot
# Unloading 215.5 kg of waste at depot
# -------------389--------------
# Unloading 193.79999999999995 kg of waste at depot
# Unloading 237.8 kg of waste at depot
# -------------390--------------
# Unloading 233.3 kg of waste at depot
# -------------391--------------
# Unloading 250.20000000000002 kg of waste at depot
# Unloading 181.39999999999998 kg of waste at depot
# -------------392--------------
# Unloading 194.29999999999998 kg of waste at depot
# -------------393--------------
# Unloading 252.9 kg of waste at depot
# Unloading 178.70000000000002 kg of waste at depot
# -------------394--------------
# Unloading 250.5 kg of waste at depot
# -------------395--------------
# Unloading 264.2 kg of waste at depot
# Unloading 167.4 kg of waste at depot
# -------------396--------------
# Unloading 243.6 kg of waste at depot
# -------------397--------------
# Unloading 154.8 kg of waste at depot
# -------------398--------------
# Unloading 218.8 kg of waste at depot
# Unloading 212.8 kg of waste at depot
# -------------399--------------
# Unloading 226.50000000000003 kg of waste at depot
# -------------400--------------
# Unloading 296.0 kg of waste at depot
# Unloading 135.6 kg of waste at depot
# -------------401--------------
# Unloading 267.20000000000005 kg of waste at depot
# Unloading 164.4 kg of waste at depot
# -------------402--------------
# Unloading 229.60000000000002 kg of waste at depot
# Unloading 202.0 kg of waste at depot
# -------------403--------------
# Unloading 192.4 kg of waste at depot
# -------------404--------------
# Unloading 149.50000000000003 kg of waste at depot
# -------------405--------------
# Unloading 215.00000000000003 kg of waste at depot
# -------------406--------------
# Unloading 260.5 kg of waste at depot
# -------------407--------------
# Unloading 281.30000000000007 kg of waste at depot
# Unloading 150.3 kg of waste at depot
# -------------408--------------
# Unloading 257.9 kg of waste at depot
# -------------409--------------
# Unloading 189.10000000000002 kg of waste at depot
# -------------410--------------
# Unloading 175.9 kg of waste at depot
# Unloading 255.69999999999996 kg of waste at depot
# -------------411--------------
# Unloading 229.0 kg of waste at depot
# Unloading 202.6 kg of waste at depot
# -------------412--------------
# Unloading 193.79999999999998 kg of waste at depot
# -------------413--------------
# Unloading 215.89999999999998 kg of waste at depot
# Unloading 215.70000000000002 kg of waste at depot
# -------------414--------------
# Unloading 246.7 kg of waste at depot
# -------------415--------------
# Unloading 190.7 kg of waste at depot
# Unloading 240.9 kg of waste at depot
# -------------416--------------
# Unloading 167.2 kg of waste at depot
# -------------417--------------
# Unloading 295.9 kg of waste at depot
# Unloading 135.7 kg of waste at depot
# -------------418--------------
# Unloading 290.29999999999995 kg of waste at depot
# Unloading 141.3 kg of waste at depot
# -------------419--------------
# Unloading 206.5 kg of waste at depot
# Unloading 225.10000000000002 kg of waste at depot
# -------------420--------------
# Unloading 264.6 kg of waste at depot
# -------------421--------------
# Unloading 200.1 kg of waste at depot
# -------------422--------------
# Unloading 216.4 kg of waste at depot
# Unloading 215.2 kg of waste at depot
# -------------423--------------
# Unloading 245.70000000000002 kg of waste at depot
# Unloading 185.9 kg of waste at depot
# -------------424--------------
# Unloading 231.19999999999996 kg of waste at depot
# -------------425--------------
# Unloading 253.5 kg of waste at depot
# Unloading 178.1 kg of waste at depot
# -------------426--------------
# Unloading 221.4 kg of waste at depot
# -------------427--------------
# Unloading 214.2 kg of waste at depot
# -------------428--------------
# Unloading 185.1 kg of waste at depot
# -------------429--------------
# Unloading 208.79999999999998 kg of waste at depot
# -------------430--------------
# Unloading 186.5 kg of waste at depot
# Unloading 245.1 kg of waste at depot
# -------------431--------------
# Unloading 261.5 kg of waste at depot
# -------------432--------------
# Unloading 182.3 kg of waste at depot
# Unloading 249.3 kg of waste at depot
# -------------433--------------
# Unloading 189.1 kg of waste at depot
# -------------434--------------
# Unloading 272.3 kg of waste at depot
# Unloading 159.3 kg of waste at depot
# -------------435--------------
# Unloading 230.2 kg of waste at depot
# -------------436--------------
# Unloading 246.5 kg of waste at depot
# -------------437--------------
# Unloading 163.0 kg of waste at depot
# -------------438--------------
# Unloading 161.89999999999998 kg of waste at depot
# -------------439--------------
# Unloading 269.7 kg of waste at depot
# Unloading 161.9 kg of waste at depot
# -------------440--------------
# Unloading 223.8 kg of waste at depot
# Unloading 207.79999999999998 kg of waste at depot
# -------------441--------------
# Unloading 281.6 kg of waste at depot
# Unloading 149.99999999999997 kg of waste at depot
# -------------442--------------
# Unloading 250.60000000000002 kg of waste at depot
# -------------443--------------
# Unloading 247.70000000000002 kg of waste at depot
# -------------444--------------
# Unloading 214.4 kg of waste at depot
# Unloading 217.20000000000002 kg of waste at depot
# -------------445--------------
# Unloading 180.1 kg of waste at depot
# Unloading 251.5 kg of waste at depot
# -------------446--------------
# Unloading 131.0 kg of waste at depot
# -------------447--------------
# Unloading 250.4 kg of waste at depot
# Unloading 181.20000000000002 kg of waste at depot
# -------------448--------------
# Unloading 234.8 kg of waste at depot
# -------------449--------------
# Unloading 216.9 kg of waste at depot
# -------------450--------------
# Unloading 200.0 kg of waste at depot
# -------------451--------------
# Unloading 251.8 kg of waste at depot
# -------------452--------------
# Unloading 257.8 kg of waste at depot
# Unloading 173.8 kg of waste at depot
# -------------453--------------
# Unloading 222.5 kg of waste at depot
# Unloading 209.1 kg of waste at depot
# -------------454--------------
# Unloading 175.0 kg of waste at depot
# -------------455--------------
# Unloading 279.7 kg of waste at depot
# Unloading 151.9 kg of waste at depot
# -------------456--------------
# Unloading 237.2 kg of waste at depot
# Unloading 194.39999999999998 kg of waste at depot
# -------------457--------------
# Unloading 272.7 kg of waste at depot
# Unloading 158.9 kg of waste at depot
# -------------458--------------
# Unloading 273.09999999999997 kg of waste at depot
# Unloading 158.5 kg of waste at depot
# -------------459--------------
# Unloading 186.20000000000002 kg of waste at depot
# -------------460--------------
# Unloading 183.4 kg of waste at depot
# -------------461--------------
# Unloading 312.4 kg of waste at depot
# Unloading 119.19999999999999 kg of waste at depot
# -------------462--------------
# Unloading 205.2 kg of waste at depot
# -------------463--------------
# Unloading 237.6 kg of waste at depot
# Unloading 193.99999999999997 kg of waste at depot
# -------------464--------------
# Unloading 159.0 kg of waste at depot
# -------------465--------------
# Unloading 202.8 kg of waste at depot
# -------------466--------------
# Unloading 227.70000000000002 kg of waste at depot
# Unloading 203.9 kg of waste at depot
# -------------467--------------
# Unloading 220.4 kg of waste at depot
# -------------468--------------
# Unloading 254.3 kg of waste at depot
# Unloading 177.29999999999998 kg of waste at depot
# -------------469--------------
# Unloading 284.7 kg of waste at depot
# Unloading 146.9 kg of waste at depot
# -------------470--------------
# Unloading 311.19999999999993 kg of waste at depot
# -------------471--------------
# Unloading 236.4 kg of waste at depot
# Unloading 195.2 kg of waste at depot
# -------------472--------------
# Unloading 178.4 kg of waste at depot
# -------------473--------------
# Unloading 257.0 kg of waste at depot
# -------------474--------------
# Unloading 273.3 kg of waste at depot
# -------------475--------------
# Unloading 245.29999999999998 kg of waste at depot
# Unloading 186.29999999999998 kg of waste at depot
# -------------476--------------
# Unloading 203.8 kg of waste at depot
# Unloading 227.8 kg of waste at depot
# -------------477--------------
# Unloading 277.59999999999997 kg of waste at depot
# Unloading 154.00000000000003 kg of waste at depot
# -------------478--------------
# Unloading 213.4 kg of waste at depot
# Unloading 218.2 kg of waste at depot
# -------------479--------------
# Unloading 219.3 kg of waste at depot
# -------------480--------------
# Unloading 289.70000000000005 kg of waste at depot
# Unloading 141.9 kg of waste at depot
# -------------481--------------
# Unloading 207.1 kg of waste at depot
# -------------482--------------
# Unloading 171.6 kg of waste at depot
# -------------483--------------
# Unloading 221.5 kg of waste at depot
# -------------484--------------
# Unloading 215.00000000000003 kg of waste at depot
# Unloading 216.60000000000002 kg of waste at depot
# -------------485--------------
# Unloading 211.59999999999997 kg of waste at depot
# -------------486--------------
# Unloading 243.00000000000003 kg of waste at depot
# -------------487--------------
# Unloading 215.4 kg of waste at depot
# Unloading 216.20000000000002 kg of waste at depot
# -------------488--------------
# Unloading 175.70000000000002 kg of waste at depot
# Unloading 255.9 kg of waste at depot
# -------------489--------------
# Unloading 153.3 kg of waste at depot
# -------------490--------------
# Unloading 216.8 kg of waste at depot
# -------------491--------------
# Unloading 181.1 kg of waste at depot
# Unloading 250.50000000000003 kg of waste at depot
# -------------492--------------
# Unloading 198.59999999999997 kg of waste at depot
# Unloading 233.0 kg of waste at depot
# -------------493--------------
# Unloading 261.9 kg of waste at depot
# -------------494--------------
# Unloading 228.2 kg of waste at depot
# -------------495--------------
# Unloading 226.79999999999995 kg of waste at depot
# -------------496--------------
# Unloading 275.0 kg of waste at depot
# Unloading 156.60000000000002 kg of waste at depot
# -------------497--------------
# Unloading 165.6 kg of waste at depot
# Unloading 266.0 kg of waste at depot
# -------------498--------------
# Unloading 154.1 kg of waste at depot
# Unloading 277.5 kg of waste at depot
# -------------499--------------
# Unloading 283.1 kg of waste at depot
# Unloading 148.5 kg of waste at depot

# %%
d2=prepPlot(routelist)
d2.keys()
# d3=prepPlot(routelist)
# d3.keys()
# Out:
# dict_keys(['x0', 'y0', 'x1', 'y1'])

# %%
makemap(d2)

# %%
print(f"Minimum distance learnt by 2 Agents in a Multi-Agent Reinforcement learning environment is {min(mean_dist)} km ")
# Out:
# Minimum distance learnt by 2 Agents in a Multi-Agent Reinforcement learning environment is 22.313750000000002 km
