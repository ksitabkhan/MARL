# %% [markdown]
# <h1>RL For waste collection</h1>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from math import sin, cos, sqrt, atan2, radians
import random

# %%
from google.colab import drive
 
drive.mount('/content/drive')

# %cd /content/drive/My Drive/Colab Notebooks/Project
# ISOT_real = pd.read_csv('ISOT_True.csv')')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/Project

# %%
position = pd.read_csv('dlrrefusebinslocations.csv',encoding='latin1')


# assigning random values for weight of waste in the bin
weights = (np.random.choice(range(0,300), size=len(position), replace=True))/10
position['weight']=weights

#The depot coordinates are stored in the CSV file. Coordinates obtained from Google 
depot = pd.read_csv('Depot.csv',encoding='latin1')

position= position.append(depot, ignore_index=True)

my_df = position.sort_values(by=['Bin no.'],ignore_index=True)
my_df
# Out:
#                                            Description  ...  weight
# 0                                            DLR Depot  ...     0.0
# 1                   AA - 1 - Foxrock Park, opposite 28  ...    23.3
# 2    AB - 2 - Foxrock Ave, beside lane opposite 59a...  ...    29.0
# 3                  AC - 3 - Foxrock Ave, outside shops  ...    22.5
# 4      AD - 4 - Kill Lane, outside Deansgrange library  ...    15.6
# ..                                                 ...  ...     ...
# 394  OTA - 395 - Bird Avenue, green area on front o...  ...    17.3
# 395  KFA - 396 - St. Raphaels Road, at bus stop bes...  ...     0.3
# 396        MVA - 397 - Chruchtown Road, at Luas bridge  ...    19.7
# 397       HKA - 398 - Arnold Park, at entrance to park  ...    22.3
# 398  HJA - 399 - Sallyglen Road - Dalkey School pro...  ...    27.9
#
# [399 rows x 5 columns]

# %%
my_df=my_df.head(n=51)
LEN=(len(my_df))
print(LEN)
# Out:
# 51

# %%
sum(my_df['weight'])
# Out:
# 768.4

# %%
#Roughly displaying the location of all the bins(blue) and depot (red) 
plt.plot(my_df['Longitude'][0], my_df['Latitude'][0], c='r', marker='s')
plt.scatter(my_df['Longitude'][1:], my_df['Latitude'][1:], c='b',s=5)

# %%
distance= np.zeros(len(my_df)*len(my_df)).reshape(len(my_df), len(my_df))

# %%
R = 6373.0 # approximate radius of earth in km
for i in range (0,len(my_df)):
    for j in range(0,len(my_df)):
        if i == j:
            distance[i,j]=float('inf')
        else : 
            lat1 = radians(my_df["Latitude"][i])
            lon1 = radians(my_df["Longitude"][i])
            lat2 = radians(my_df["Latitude"][j])
            lon2 = radians(my_df["Longitude"][j])
            dlon = lon2 - lon1
            dlat = lat2 - lat1
            a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
            c = 2 * atan2(sqrt(a), sqrt(1 - a))

            distance[i,j] = round(R * c ,4)
#             print("\n")

# %%
print(f"Shape of the distance matrix is: {distance.shape}")
# Out:
# Shape of the distance matrix is: (51, 51)

# %%
distance
# Out:
# array([[   inf, 3.364 , 3.4434, ..., 0.6128, 0.6435, 0.7019],
#        [3.364 ,    inf, 0.2611, ..., 3.2895, 3.2792, 3.2604],
#        [3.4434, 0.2611,    inf, ..., 3.3229, 3.3103, 3.287 ],
#        ...,
#        [0.6128, 3.2895, 3.3229, ...,    inf, 0.032 , 0.0928],
#        [0.6435, 3.2792, 3.3103, ..., 0.032 ,    inf, 0.0607],
#        [0.7019, 3.2604, 3.287 , ..., 0.0928, 0.0607,    inf]])

# %%
def prepPlot(FINAL_ROUTE):
    i=0
    d={}
    d1={}
    for key in FINAL_ROUTE:
        x=[]
        y=[]
        var1='x'+str(key)
        var2='y'+str(key)
        d1[key]=list([var1,var2])
        listed= FINAL_ROUTE[key]
        for i in listed:
            x.append(my_df.iloc[i]['Latitude'])
            y.append(my_df.iloc[i]['Longitude'])
        d[var1]=x
        d[var2]=y
    return d
#          y.append(my_df[my_df['Bin no.']==i]['Longitude'].values[0])

# %%
def makemap(d):
    from matplotlib.pyplot import figure

    figure(figsize=(8, 6), dpi=80)
    for i in range(int((len(d))/2)):
        var1='y'+str(i)
        var2='x'+str(i)

        plt.plot(d[var1],d[var2])
    
    
    plt.scatter(my_df['Longitude'][1:], my_df['Latitude'][1:], c='g',s=10,label='bin')
    plt.scatter(my_df['Longitude'][0], my_df['Latitude'][0], c='r',marker='s', label='depot')

    plt.legend(loc='upper right');   
    if(int(len(d)/2) == 1):
        plt.title("DLR Refuse Bins for single agent")
    else:
        plt.title("DLR Refuse Bins for mutiple agents")
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.show()

# %%
class AgentSystem():
    def __init__(self):
        self.capacity=0
        self.distance_covered=0
        self.near_nodes=[]
        self.near_node_weight=[]
        self.near_node_dist=[]
        self.curr_node=0
        self.route_list=[0]
        self.agent_id=0
        self.total_dist=[]
        

    def return_depo(self):
        global depo_capacity
        depo_capacity = depo_capacity + self.capacity
        print(f"Distance covered by {self.agent_id} the node is {round(self.distance_covered,2)}")
        
        self.total_dist.append(round(self.distance_covered,2))
        self.capacity=0

        print(f"for {self.agent_id} the route is ")
        print(self.route_list)
        global FINAL_ROUTE, DIST_TOTAL
#         DIST_TOTAL+=self.distance_covered
        try:
            if len(FINAL_ROUTE[self.agent_id]) != 0:
                DIST_TOTAL[self.agent_id] += self.distance_covered
                temp_list=[]
                temp_list=FINAL_ROUTE[self.agent_id] + self.route_list
                FINAL_ROUTE[self.agent_id]=temp_list
        except KeyError:
            FINAL_ROUTE[self.agent_id]=self.route_list
            DIST_TOTAL[self.agent_id]=self.distance_covered
        
        self.distance_covered=0
        self.route_list=[0]
        print("----------------")

    def next_stop(self, next_node):
        self.route_list.append(next_node)
        
        self.curr_node = next_node
        if self.curr_node != depot_node:
            next_node_cap=self.df[self.df['Node']==next_node]['Weight'].values[0]
            next_node_dist=self.df[self.df['Node']==next_node]['Distance'].values[0]
            if (next_node_dist == float('inf')):
              next_node_dist = 0
            self.distance_covered += next_node_dist
            self.capacity += next_node_cap
            if(self.capacity> truck_cap):

                weight[self.curr_node]= self.capacity - truck_cap
                self.capacity = truck_cap
            
            else: 
                weight[self.curr_node]=0
            
        else:
            self.return_depo()
        
        
    def select_action(self):
        
        min_dist= min(self.df["Distance"])
        near_node=self.df[self.df['Distance']== min_dist]['Node'].values[0]
        near_node_cap=self.df[self.df['Node']==near_node]['Weight'].values[0]
        if (near_node_cap == 0):
            random_node = np.random.choice(self.df['Node'])
            # print(f"{self.df['Node']}")
            # near_node=self.df[self.df['Distance']== min_dist]['Node'].values[0]
            near_node_cap=self.df[self.df['Node']==random_node]['Weight'].values[0]
            near_node=random_node
            # print(f"Randomly chosen node is {near_node}")

        if (self.capacity < truck_cap):
            next_node=near_node
            self.distance_covered +=min_dist
            self.capacity += near_node_cap
            self.next_stop(next_node)
            
        else:
            self.next_stop(depot_node)
            

        
    def update_statespace(self,agent_id):
        self.agent_id=agent_id
        A= distance[self.curr_node][:]
        self.near_nodes=list(np.argsort(A))
        self.near_node_dist=list(distance[self.curr_node][self.near_nodes])
        self.near_node_weight=list(weight[self.near_nodes])
        self.df=pd.DataFrame(list(zip(self.near_nodes,self.near_node_dist,self.near_node_weight)),
                             columns = ['Node','Distance', 'Weight'])
        # self.df = self.df[(self.df['Weight'] > 0)]
        # self.df = self.df.nsmallest(10, 'Distance')
        if self.df.empty:
            print('DataFrame is empty!')
            self.next_stop(depot_node)
            return 1
        else:
            self.select_action()
        return (self.total_dist)

# %%
depo_capacity=0
depot_node=0
bins_left=len(my_df)-1
truck_cap=700
weight = pd.Series(list(my_df['weight']))
FINAL_ROUTE={}
DIST_TOTAL={}
city_waste=sum(my_df['weight'])

# %%
distance_covered=[]
agent=AgentSystem()
while(depo_capacity < 1.4*round(city_waste,2)):
    distance_covered.append(agent.update_statespace(0))
# Out:
# Distance covered by 0 the node is 32.23
# for 0 the route is
# [0, 48, 47, 49, 12, 11, 10, 28, 27, 26, 12, 28, 20, 21, 22, 23, 13, 14, 15, 21, 44, 46, 12, 13, 37, 38, 4, 5, 16, 17, 50, 0]
# ----------------
# Distance covered by 0 the node is 107.52
# for 0 the route is
# [0, 19, 18, 47, 17, 38, 41, 42, 13, 2, 3, 28, 21, 12, 23, 35, 34, 32, 31, 23, 33, 15, 50, 50, 3, 37, 14, 43, 18, 7, 6, 45, 34, 46, 39, 4, 42, 35, 41, 17, 22, 6, 17, 41, 14, 42, 7, 12, 14, 46, 36, 9, 8, 42, 20, 35, 15, 45, 15, 41, 6, 35, 20, 17, 44, 10, 8, 8, 33, 21, 11, 21, 1, 0]
# ----------------

# %%
d1=prepPlot(FINAL_ROUTE)
makemap(d1)

# %%
print(distance_covered[1])
plt.plot(distance_covered[1])
plt.scatter(range(0,len(distance_covered[1])),distance_covered[1])
plt.title("Distance Covered in Each route")
plt.xlabel("Route number")
plt.ylabel("Distance Covered")
plt.xticks(range(0,1,2))
plt.show
# Out:
# [32.23, 107.52]
# <function matplotlib.pyplot.show>

# %%
for key in DIST_TOTAL:
    print(f"The time taken for agent {key} to cover a distance of {round(DIST_TOTAL[key],2)} km is {round(DIST_TOTAL[key]/18.1,2)} hours")
# Out:
# The time taken for agent 0 to cover a distance of 139.75 km is 7.72 hours

# %%
depo_capacity=0
depot_node=0
bins_left=len(my_df)-1
truck_cap=700
weight = pd.Series(list(my_df['weight']))
FINAL_ROUTE={}
# DIST_TOTAL=0
DIST_TOTAL={}

# %%
for x in range(0, 9):
    globals()['Agent%s' % x] = AgentSystem()

while(depo_capacity < 1.4*round(city_waste,2)):

    Agent0.update_statespace(0)
    Agent1.update_statespace(1)
# Out:
# Distance covered by 1 the node is 14.0
# for 1 the route is
# [0, 18, 17, 16, 15, 27, 26, 10, 11, 37, 38, 37, 41, 20, 24, 0]
# ----------------
# Distance covered by 1 the node is 0.61
# for 1 the route is
# [0, 0]
# ----------------
# Distance covered by 0 the node is 39.75
# for 0 the route is
# [0, 48, 47, 49, 15, 14, 47, 2, 3, 40, 41, 42, 20, 21, 22, 23, 48, 18, 38, 11, 20, 9, 8, 6, 7, 34, 25, 19, 9, 46, 44, 42, 28, 31, 37, 16, 15, 41, 31, 0]
# ----------------
# Distance covered by 1 the node is 41.83
# for 1 the route is
# [0, 19, 22, 34, 35, 48, 28, 23, 29, 1, 20, 11, 42, 9, 15, 31, 32, 1, 50, 49, 28, 2, 1, 21, 12, 20, 37, 44, 43, 0]
# ----------------

# %%
for key in DIST_TOTAL:
    print(f"The time taken for agent {key} to cover a distance of {round(DIST_TOTAL[key],2)} km is {round(DIST_TOTAL[key]*60/18.1,2)} minutes")
# Out:
# The time taken for agent 1 to cover a distance of 56.44 km is 187.1 minutes
# The time taken for agent 0 to cover a distance of 39.75 km is 131.78 minutes

# %%
# AVERAGE_PER_AGENT=round(sum(DIST_TOTAL.values())*60/(len(DIST_TOTAL.keys())*18.1),2)
# print(f"\n\nThe average time taken for each agent to go across its path is {AVERAGE_PER_AGENT} minutes")
AVERAGE_PER_AGENT=round(sum(DIST_TOTAL.values())*60/(len(DIST_TOTAL.keys())*18.1),2)
print(f"\n\nThe average time taken for each agent to go across its path is {AVERAGE_PER_AGENT/60} hours and average distance is {round(sum(DIST_TOTAL.values())/len(DIST_TOTAL.values()),2)} km")
# Out:
# The average time taken for each agent to go across its path is 2.6573333333333333 hours and average distance is 48.1 km

# %%
d=prepPlot(FINAL_ROUTE)

# d['x0']=[]
# d['y0']=[]
makemap(d)

# %%
# DIST_TOTAL.values()
plt.bar(DIST_TOTAL.keys(),DIST_TOTAL.values())
# plt.plot(DIST_TOTAL.values())
plt.xticks([0,1])
# plt.yticks([0,20,40,60,80,100,120])
# plt.ylim(50, 120)
plt.title("Distance Covered By Each Agent in a Multi-agent System")
plt.xlabel("Agent number")
plt.ylabel("Distance Covered")
# Out:
# Text(0, 0.5, 'Distance Covered')

# %%
depo_capacity=0
DEPOT_NODE=0
bins_left=len(my_df)-1
TRUCK_CAP=700
ITERATION_NUMBER=0
weight = pd.Series(list(my_df['weight']))
DF_LEN = len(distance)

# %%
class Environment():
    def __init__(self,curr_node=DEPOT_NODE):
        self.curr_node=0
        self.isEnd = False 
        self.StateSpace = pd.DataFrame()
        self.weight=pd.Series(list(my_df['weight']))
        self.distance=distance
        self.prev_node=0
        
    def getReward(self,node,capacity,distance_covered):
        if self.curr_node == DEPOT_NODE:
            if capacity >= 0.9*TRUCK_CAP:
                return 20
            elif sum(self.weight) < 0.00001: # to avoid issues with floating point comparison
                return 10
            else:
                return -50
        else:
            if capacity == self.prev_capacity or self.curr_node == self.prev_node:
                temp_reward=-10
            else:
                temp_reward=0
            return (capacity*10 + (distance_covered * 10)+ temp_reward)

    def isEndFunc(self,capacity):
        if (sum(self.weight)==0):
        # if (self.curr_node == DEPOT_NODE and (capacity >= TRUCK_CAP or sum(self.weight)== 0)):
            print(f"Unloading {capacity} kg of waste at depot")
            self.isEnd = True



    def update_statespace(self, new_node):   #,agent_id):
        A= self.distance[new_node][:]
        self.near_nodes=list(np.argsort(A))
        self.near_node_dist=list(self.distance[new_node][self.near_nodes])
        self.near_node_weight=list(self.weight[self.near_nodes])
        self.StateSpace=pd.DataFrame(list(zip(self.near_nodes,self.near_node_dist,self.near_node_weight)),
                             columns = ['Node','Distance', 'Weight'])

        if self.StateSpace.empty:
            print('DataFrame is empty!')
        return (self.StateSpace)   
    
    def next_position(self,node,action,capacity):   # To add update weight  
        StateSpace=self.update_statespace(node)
        dist=0
        if action in range(1,LEN) :
            self.prev_node = node
            self.curr_node = StateSpace['Node'].iloc[action]
            self.prev_capacity=capacity
            capacity += StateSpace[StateSpace['Node']==self.curr_node]['Weight'].values[0]
            self.weight[self.curr_node]=0
            dist = StateSpace[StateSpace['Node']==self.curr_node]['Distance'].values[0]
                
        elif action == 0 :
            self.curr_node = DEPOT_NODE
            capacity=0
            dist=StateSpace[StateSpace['Node']==DEPOT_NODE]['Distance'].values[0]
            self.isEndFunc(capacity)
        else:
            print(f"In error state Value of action is {action}")
        StateSpace = self.update_statespace(self.curr_node)
        if (dist == float('inf')):
              dist=0
        return self.curr_node,capacity,dist

# %%
class AgentRL():
    def __init__(self):

        self.actions = list(range(0,LEN))    
        self.alpha = 0.5
        self.gamma = 0.9
        self.epsilon = 0.5
        self.plot_reward = []
        self.Q = {}
        self.new_Q = {}
        self.reward=0
        
        for i in range(DF_LEN):
            for k in range(len(self.actions)):  # initialising a 398 x 6 matrix
                self.Q[(i,k)] =0
                self.new_Q[(i, k)] = 0
    def ResetParams(self):
        self.route_list=[0]
        self.capacity=0
        self.isEnd=False
        self.distance_covered=0
        self.curr_node=0
      #self.env=Environment()
    def showValues(self):
        for i in range(0, DF_LEN):
            out = '| '
            mx_nxt_value = -10
            for a in self.actions:
                nxt_value = self.Q[(i,a)]
                if nxt_value >= mx_nxt_value:
                    mx_nxt_value = nxt_value
            out += str(mx_nxt_value).ljust(6) + ' | '
#         print(out)

    def plot(self,routelist_len):
        
        plt.plot(routelist_len)
        plt.show()

    def Action(self,env):
        rnd = random.random()
        mx_nxt_reward =-100
        action = None
        if self.capacity >= 0.9* TRUCK_CAP or self.isEnd:
          action = 0
        elif (self.epsilon > rnd) :
            #iterate through actions, find Q  value and choose best 
            for k in self.actions:
                
                i = env.curr_node
                
                nxt_reward = self.Q[(i, k)]
                
                if nxt_reward >= mx_nxt_reward:
                    action = k
                    mx_nxt_reward = nxt_reward
                    # print(f"mx_nxt_reward = {mx_nxt_reward} for i={i} and k={k}")
        else:
            dummylist=self.actions[:]
            dummylist.remove(0)

            action = np.random.choice(dummylist)
  
        self.curr_node,self.capacity,dist = env.next_position(self.curr_node,action,self.capacity)
        self.distance_covered +=dist
        self.route_list.append(self.curr_node)
        global ITERATION_NUMBER
        ITERATION_NUMBER +=1
        # print(f"-------------Iteration is {ITERATION_NUMBER}\n Value of Action is {action}")
        return self.curr_node,action

        
    def Q_Learning(self,env,epsilon,agentId):
        self.epsilon=epsilon
        capacity = self.capacity
        self.agentId=agentId

        env.isEndFunc(self.capacity)
        self.isEnd=env.isEnd
        if (not self.isEnd):
            mx_nxt_value = -10
            next_node, action = self.Action(env)
            i = next_node
            reward = env.getReward(self.curr_node,self.capacity,self.distance_covered)
            self.reward +=reward
            for a in self.actions:
                nxtEnvironmentAction = (next_node, a)
                q_value = (1-self.alpha)*self.Q[(i,action)] + self.alpha*(reward + self.gamma*self.Q[nxtEnvironmentAction])
                if q_value >= mx_nxt_value:
                    mx_nxt_value = q_value
            env.isEndFunc(self.capacity)
            self.isEnd = env.isEnd
            self.new_Q[(i,action)] = round(mx_nxt_value,3)
          # else:

        self.Q = self.new_Q.copy()
        # print(mx_nxt_value)
        # print(f"Distance covered is {self.distance_covered}")
        return self.route_list,self.distance_covered

# %% [markdown]
# **Running Single Agent RL system**

# %%
if __name__ == "__main__":
    episodes=500
    i=0
    
    ag=AgentRL()
    
    ag.ResetParams()
    ag2=AgentRL()
    ag2.ResetParams()
    env=Environment()
    IsEnd=False  
    routelist_len=[]
    distance_cov=[]
    FINAL_ROUTE1={}
    FINAL_2={}
    epsilon=0.8
    DIST_TOTAL={}
    routelist={}
    routelist0={}
    routelist1={}
    dist2_cov=[]
    while (i<episodes):
        epsilon = 0.95*epsilon
        print(f"-------------{i}--------------")
        IsEnd=False  
        env=Environment()
        ag.ResetParams()
        ag2.ResetParams()
        env.weight=pd.Series(list(my_df['weight']))
        while (int (sum(env.weight))>0):
            routelist0[i],distance_covered=ag.Q_Learning(env,epsilon,0)
            # routelist1[i],dist2_covd=ag2.Q_Learning(env,epsilon,1)
        
        distance_cov.append(distance_covered)
        # dist2_cov.append(dist2_covd)
        routelist_len.append(len(routelist0[0]))
        i +=1
    min_route=routelist_len.index(min(routelist_len))
    routelist[0]=routelist0[min_route]
    # routelist[1]=routelist1[min_route]
    plt.plot(distance_cov)
    # plt.plot(dist2_cov)
    # plt.ylim(0,500)
    # ag.plot(routelist_len)
    # ag.showValues
# Out:
# -------------0--------------
# Unloading 136.1 kg of waste at depot
# -------------1--------------
# Unloading 133.7 kg of waste at depot
# -------------2--------------
# Unloading 134.20000000000002 kg of waste at depot
# -------------3--------------
# Unloading 137.5 kg of waste at depot
# -------------4--------------
# Unloading 132.20000000000002 kg of waste at depot
# -------------5--------------
# Unloading 131.7 kg of waste at depot
# -------------6--------------
# Unloading 135.5 kg of waste at depot
# -------------7--------------
# Unloading 124.0 kg of waste at depot
# -------------8--------------
# Unloading 132.4 kg of waste at depot
# -------------9--------------
# Unloading 128.6 kg of waste at depot
# -------------10--------------
# Unloading 135.89999999999998 kg of waste at depot
# -------------11--------------
# Unloading 132.1 kg of waste at depot
# -------------12--------------
# Unloading 119.8 kg of waste at depot
# -------------13--------------
# Unloading 127.19999999999999 kg of waste at depot
# -------------14--------------
# Unloading 122.19999999999999 kg of waste at depot
# -------------15--------------
# Unloading 124.4 kg of waste at depot
# -------------16--------------
# Unloading 135.0 kg of waste at depot
# -------------17--------------
# Unloading 129.6 kg of waste at depot
# -------------18--------------
# Unloading 129.4 kg of waste at depot
# -------------19--------------
# Unloading 131.89999999999998 kg of waste at depot
# -------------20--------------
# Unloading 137.89999999999998 kg of waste at depot
# -------------21--------------
# Unloading 136.8 kg of waste at depot
# -------------22--------------
# Unloading 133.3 kg of waste at depot
# -------------23--------------
# Unloading 131.4 kg of waste at depot
# -------------24--------------
# Unloading 131.2 kg of waste at depot
# -------------25--------------
# Unloading 124.60000000000001 kg of waste at depot
# -------------26--------------
# Unloading 137.4 kg of waste at depot
# -------------27--------------
# Unloading 121.4 kg of waste at depot
# -------------28--------------
# Unloading 125.19999999999999 kg of waste at depot
# -------------29--------------
# Unloading 125.89999999999998 kg of waste at depot
# -------------30--------------
# Unloading 138.1 kg of waste at depot
# -------------31--------------
# Unloading 116.6 kg of waste at depot
# -------------32--------------
# Unloading 117.5 kg of waste at depot
# -------------33--------------
# Unloading 124.10000000000002 kg of waste at depot
# -------------34--------------
# Unloading 133.6 kg of waste at depot
# -------------35--------------
# Unloading 126.19999999999999 kg of waste at depot
# -------------36--------------
# Unloading 136.20000000000002 kg of waste at depot
# -------------37--------------
# Unloading 137.1 kg of waste at depot
# -------------38--------------
# Unloading 118.2 kg of waste at depot
# -------------39--------------
# Unloading 132.9 kg of waste at depot
# -------------40--------------
# Unloading 119.8 kg of waste at depot
# -------------41--------------
# Unloading 129.1 kg of waste at depot
# -------------42--------------
# Unloading 128.10000000000002 kg of waste at depot
# -------------43--------------
# Unloading 135.7 kg of waste at depot
# -------------44--------------
# Unloading 135.1 kg of waste at depot
# -------------45--------------
# Unloading 126.80000000000001 kg of waste at depot
# -------------46--------------
# Unloading 135.4 kg of waste at depot
# -------------47--------------
# Unloading 135.8 kg of waste at depot
# -------------48--------------
# Unloading 137.5 kg of waste at depot
# -------------49--------------
# Unloading 136.70000000000002 kg of waste at depot
# -------------50--------------
# Unloading 137.2 kg of waste at depot
# -------------51--------------
# Unloading 136.89999999999998 kg of waste at depot
# -------------52--------------
# Unloading 128.10000000000002 kg of waste at depot
# -------------53--------------
# Unloading 129.0 kg of waste at depot
# -------------54--------------
# Unloading 117.1 kg of waste at depot
# -------------55--------------
# Unloading 131.5 kg of waste at depot
# -------------56--------------
# Unloading 129.49999999999997 kg of waste at depot
# -------------57--------------
# Unloading 128.70000000000002 kg of waste at depot
# -------------58--------------
# Unloading 137.0 kg of waste at depot
# -------------59--------------
# Unloading 128.1 kg of waste at depot
# -------------60--------------
# Unloading 132.4 kg of waste at depot
# -------------61--------------
# Unloading 132.2 kg of waste at depot
# -------------62--------------
# Unloading 136.5 kg of waste at depot
# -------------63--------------
# Unloading 131.2 kg of waste at depot
# -------------64--------------
# Unloading 122.50000000000001 kg of waste at depot
# -------------65--------------
# Unloading 130.5 kg of waste at depot
# -------------66--------------
# Unloading 132.9 kg of waste at depot
# -------------67--------------
# Unloading 119.2 kg of waste at depot
# -------------68--------------
# Unloading 133.0 kg of waste at depot
# -------------69--------------
# Unloading 137.20000000000002 kg of waste at depot
# -------------70--------------
# Unloading 129.9 kg of waste at depot
# -------------71--------------
# Unloading 135.5 kg of waste at depot
# -------------72--------------
# Unloading 121.7 kg of waste at depot
# -------------73--------------
# Unloading 121.5 kg of waste at depot
# -------------74--------------
# Unloading 127.3 kg of waste at depot
# -------------75--------------
# Unloading 119.0 kg of waste at depot
# -------------76--------------
# Unloading 120.89999999999999 kg of waste at depot
# -------------77--------------
# Unloading 133.60000000000002 kg of waste at depot
# -------------78--------------
# Unloading 126.8 kg of waste at depot
# -------------79--------------
# Unloading 137.20000000000002 kg of waste at depot
# -------------80--------------
# Unloading 136.6 kg of waste at depot
# -------------81--------------
# Unloading 133.0 kg of waste at depot
# -------------82--------------
# Unloading 135.2 kg of waste at depot
# -------------83--------------
# Unloading 133.8 kg of waste at depot
# -------------84--------------
# Unloading 117.9 kg of waste at depot
# -------------85--------------
# Unloading 133.6 kg of waste at depot
# -------------86--------------
# Unloading 128.10000000000002 kg of waste at depot
# -------------87--------------
# Unloading 122.6 kg of waste at depot
# -------------88--------------
# Unloading 135.1 kg of waste at depot
# -------------89--------------
# Unloading 119.09999999999998 kg of waste at depot
# -------------90--------------
# Unloading 123.0 kg of waste at depot
# -------------91--------------
# Unloading 135.1 kg of waste at depot
# -------------92--------------
# Unloading 126.69999999999999 kg of waste at depot
# -------------93--------------
# Unloading 120.29999999999998 kg of waste at depot
# -------------94--------------
# Unloading 138.1 kg of waste at depot
# -------------95--------------
# Unloading 130.3 kg of waste at depot
# -------------96--------------
# Unloading 126.70000000000002 kg of waste at depot
# -------------97--------------
# Unloading 117.6 kg of waste at depot
# -------------98--------------
# Unloading 137.7 kg of waste at depot
# -------------99--------------
# Unloading 138.2 kg of waste at depot
# -------------100--------------
# Unloading 116.30000000000001 kg of waste at depot
# -------------101--------------
# Unloading 131.20000000000002 kg of waste at depot
# -------------102--------------
# Unloading 134.60000000000002 kg of waste at depot
# -------------103--------------
# Unloading 120.1 kg of waste at depot
# -------------104--------------
# Unloading 126.69999999999999 kg of waste at depot
# -------------105--------------
# Unloading 130.9 kg of waste at depot
# -------------106--------------
# Unloading 135.4 kg of waste at depot
# -------------107--------------
# Unloading 129.5 kg of waste at depot
# -------------108--------------
# Unloading 123.5 kg of waste at depot
# -------------109--------------
# Unloading 128.79999999999998 kg of waste at depot
# -------------110--------------
# Unloading 136.6 kg of waste at depot
# -------------111--------------
# Unloading 132.2 kg of waste at depot
# -------------112--------------
# Unloading 126.5 kg of waste at depot
# -------------113--------------
# Unloading 135.5 kg of waste at depot
# -------------114--------------
# Unloading 136.2 kg of waste at depot
# -------------115--------------
# Unloading 125.9 kg of waste at depot
# -------------116--------------
# Unloading 136.7 kg of waste at depot
# -------------117--------------
# Unloading 117.49999999999999 kg of waste at depot
# -------------118--------------
# Unloading 128.6 kg of waste at depot
# -------------119--------------
# Unloading 136.5 kg of waste at depot
# -------------120--------------
# Unloading 131.70000000000002 kg of waste at depot
# -------------121--------------
# Unloading 132.0 kg of waste at depot
# -------------122--------------
# Unloading 120.00000000000001 kg of waste at depot
# -------------123--------------
# Unloading 137.3 kg of waste at depot
# -------------124--------------
# Unloading 125.5 kg of waste at depot
# -------------125--------------
# Unloading 124.3 kg of waste at depot
# -------------126--------------
# Unloading 137.4 kg of waste at depot
# -------------127--------------
# Unloading 127.4 kg of waste at depot
# -------------128--------------
# Unloading 135.0 kg of waste at depot
# -------------129--------------
# Unloading 129.6 kg of waste at depot
# -------------130--------------
# Unloading 136.9 kg of waste at depot
# -------------131--------------
# Unloading 134.0 kg of waste at depot
# -------------132--------------
# Unloading 130.3 kg of waste at depot
# -------------133--------------
# Unloading 130.8 kg of waste at depot
# -------------134--------------
# Unloading 133.0 kg of waste at depot
# -------------135--------------
# Unloading 118.49999999999999 kg of waste at depot
# -------------136--------------
# Unloading 120.3 kg of waste at depot
# -------------137--------------
# Unloading 126.5 kg of waste at depot
# -------------138--------------
# Unloading 131.89999999999998 kg of waste at depot
# -------------139--------------
# Unloading 125.60000000000001 kg of waste at depot
# -------------140--------------
# Unloading 130.7 kg of waste at depot
# -------------141--------------
# Unloading 126.8 kg of waste at depot
# -------------142--------------
# Unloading 134.7 kg of waste at depot
# -------------143--------------
# Unloading 138.2 kg of waste at depot
# -------------144--------------
# Unloading 126.30000000000001 kg of waste at depot
# -------------145--------------
# Unloading 134.2 kg of waste at depot
# -------------146--------------
# Unloading 130.7 kg of waste at depot
# -------------147--------------
# Unloading 119.29999999999998 kg of waste at depot
# -------------148--------------
# Unloading 134.3 kg of waste at depot
# -------------149--------------
# Unloading 122.7 kg of waste at depot
# -------------150--------------
# Unloading 131.1 kg of waste at depot
# -------------151--------------
# Unloading 131.5 kg of waste at depot
# -------------152--------------
# Unloading 138.3 kg of waste at depot
# -------------153--------------
# Unloading 132.4 kg of waste at depot
# -------------154--------------
# Unloading 125.4 kg of waste at depot
# -------------155--------------
# Unloading 135.6 kg of waste at depot
# -------------156--------------
# Unloading 134.3 kg of waste at depot
# -------------157--------------
# Unloading 120.9 kg of waste at depot
# -------------158--------------
# Unloading 131.6 kg of waste at depot
# -------------159--------------
# Unloading 138.0 kg of waste at depot
# -------------160--------------
# Unloading 119.2 kg of waste at depot
# -------------161--------------
# Unloading 128.0 kg of waste at depot
# -------------162--------------
# Unloading 120.8 kg of waste at depot
# -------------163--------------
# Unloading 136.5 kg of waste at depot
# -------------164--------------
# Unloading 135.79999999999998 kg of waste at depot
# -------------165--------------
# Unloading 127.80000000000001 kg of waste at depot
# -------------166--------------
# Unloading 130.9 kg of waste at depot
# -------------167--------------
# Unloading 126.30000000000001 kg of waste at depot
# -------------168--------------
# Unloading 137.1 kg of waste at depot
# -------------169--------------
# Unloading 118.30000000000001 kg of waste at depot
# -------------170--------------
# Unloading 137.5 kg of waste at depot
# -------------171--------------
# Unloading 134.0 kg of waste at depot
# -------------172--------------
# Unloading 124.5 kg of waste at depot
# -------------173--------------
# Unloading 122.4 kg of waste at depot
# -------------174--------------
# Unloading 137.3 kg of waste at depot
# -------------175--------------
# Unloading 120.7 kg of waste at depot
# -------------176--------------
# Unloading 128.70000000000002 kg of waste at depot
# -------------177--------------
# Unloading 136.40000000000003 kg of waste at depot
# -------------178--------------
# Unloading 134.0 kg of waste at depot
# -------------179--------------
# Unloading 134.29999999999998 kg of waste at depot
# -------------180--------------
# Unloading 131.29999999999998 kg of waste at depot
# -------------181--------------
# Unloading 120.7 kg of waste at depot
# -------------182--------------
# Unloading 134.39999999999998 kg of waste at depot
# -------------183--------------
# Unloading 119.4 kg of waste at depot
# -------------184--------------
# Unloading 124.6 kg of waste at depot
# -------------185--------------
# Unloading 122.2 kg of waste at depot
# -------------186--------------
# Unloading 136.5 kg of waste at depot
# -------------187--------------
# Unloading 134.20000000000002 kg of waste at depot
# -------------188--------------
# Unloading 137.8 kg of waste at depot
# -------------189--------------
# Unloading 119.69999999999999 kg of waste at depot
# -------------190--------------
# Unloading 133.7 kg of waste at depot
# -------------191--------------
# Unloading 133.9 kg of waste at depot
# -------------192--------------
# Unloading 123.5 kg of waste at depot
# -------------193--------------
# Unloading 122.4 kg of waste at depot
# -------------194--------------
# Unloading 128.70000000000002 kg of waste at depot
# -------------195--------------
# Unloading 132.2 kg of waste at depot
# -------------196--------------
# Unloading 138.29999999999998 kg of waste at depot
# -------------197--------------
# Unloading 136.4 kg of waste at depot
# -------------198--------------
# Unloading 113.70000000000002 kg of waste at depot
# -------------199--------------
# Unloading 135.20000000000002 kg of waste at depot
# -------------200--------------
# Unloading 133.3 kg of waste at depot
# -------------201--------------
# Unloading 136.8 kg of waste at depot
# -------------202--------------
# Unloading 131.5 kg of waste at depot
# -------------203--------------
# Unloading 134.70000000000002 kg of waste at depot
# -------------204--------------
# Unloading 131.5 kg of waste at depot
# -------------205--------------
# Unloading 135.29999999999998 kg of waste at depot
# -------------206--------------
# Unloading 128.0 kg of waste at depot
# -------------207--------------
# Unloading 117.30000000000001 kg of waste at depot
# -------------208--------------
# Unloading 110.4 kg of waste at depot
# -------------209--------------
# Unloading 131.0 kg of waste at depot
# -------------210--------------
# Unloading 113.4 kg of waste at depot
# -------------211--------------
# Unloading 119.0 kg of waste at depot
# -------------212--------------
# Unloading 121.5 kg of waste at depot
# -------------213--------------
# Unloading 123.10000000000001 kg of waste at depot
# -------------214--------------
# Unloading 132.2 kg of waste at depot
# -------------215--------------
# Unloading 119.6 kg of waste at depot
# -------------216--------------
# Unloading 121.00000000000001 kg of waste at depot
# -------------217--------------
# Unloading 113.80000000000001 kg of waste at depot
# -------------218--------------
# Unloading 127.8 kg of waste at depot
# -------------219--------------
# Unloading 136.8 kg of waste at depot
# -------------220--------------
# Unloading 137.5 kg of waste at depot
# -------------221--------------
# Unloading 138.1 kg of waste at depot
# -------------222--------------
# Unloading 125.0 kg of waste at depot
# -------------223--------------
# Unloading 125.2 kg of waste at depot
# -------------224--------------
# Unloading 128.4 kg of waste at depot
# -------------225--------------
# Unloading 135.3 kg of waste at depot
# -------------226--------------
# Unloading 137.70000000000002 kg of waste at depot
# -------------227--------------
# Unloading 109.79999999999998 kg of waste at depot
# -------------228--------------
# Unloading 132.2 kg of waste at depot
# -------------229--------------
# Unloading 125.0 kg of waste at depot
# -------------230--------------
# Unloading 126.19999999999999 kg of waste at depot
# -------------231--------------
# Unloading 128.9 kg of waste at depot
# -------------232--------------
# Unloading 125.1 kg of waste at depot
# -------------233--------------
# Unloading 131.8 kg of waste at depot
# -------------234--------------
# Unloading 137.70000000000002 kg of waste at depot
# -------------235--------------
# Unloading 137.0 kg of waste at depot
# -------------236--------------
# Unloading 132.0 kg of waste at depot
# -------------237--------------
# Unloading 120.30000000000001 kg of waste at depot
# -------------238--------------
# Unloading 137.0 kg of waste at depot
# -------------239--------------
# Unloading 128.8 kg of waste at depot
# -------------240--------------
# Unloading 135.79999999999998 kg of waste at depot
# -------------241--------------
# Unloading 133.29999999999998 kg of waste at depot
# -------------242--------------
# Unloading 113.60000000000001 kg of waste at depot
# -------------243--------------
# Unloading 119.60000000000002 kg of waste at depot
# -------------244--------------
# Unloading 128.8 kg of waste at depot
# -------------245--------------
# Unloading 123.10000000000001 kg of waste at depot
# -------------246--------------
# Unloading 128.59999999999997 kg of waste at depot
# -------------247--------------
# Unloading 137.70000000000002 kg of waste at depot
# -------------248--------------
# Unloading 116.8 kg of waste at depot
# -------------249--------------
# Unloading 130.8 kg of waste at depot
# -------------250--------------
# Unloading 125.29999999999998 kg of waste at depot
# -------------251--------------
# Unloading 133.6 kg of waste at depot
# -------------252--------------
# Unloading 134.79999999999998 kg of waste at depot
# -------------253--------------
# Unloading 117.10000000000001 kg of waste at depot
# -------------254--------------
# Unloading 128.00000000000003 kg of waste at depot
# -------------255--------------
# Unloading 133.60000000000002 kg of waste at depot
# -------------256--------------
# Unloading 122.6 kg of waste at depot
# -------------257--------------
# Unloading 130.39999999999998 kg of waste at depot
# -------------258--------------
# Unloading 120.6 kg of waste at depot
# -------------259--------------
# Unloading 134.3 kg of waste at depot
# -------------260--------------
# Unloading 123.69999999999999 kg of waste at depot
# -------------261--------------
# Unloading 116.10000000000001 kg of waste at depot
# -------------262--------------
# Unloading 132.9 kg of waste at depot
# -------------263--------------
# Unloading 129.2 kg of waste at depot
# -------------264--------------
# Unloading 126.20000000000002 kg of waste at depot
# -------------265--------------
# Unloading 131.89999999999998 kg of waste at depot
# -------------266--------------
# Unloading 133.6 kg of waste at depot
# -------------267--------------
# Unloading 113.3 kg of waste at depot
# -------------268--------------
# Unloading 132.7 kg of waste at depot
# -------------269--------------
# Unloading 136.9 kg of waste at depot
# -------------270--------------
# Unloading 136.9 kg of waste at depot
# -------------271--------------
# Unloading 125.89999999999999 kg of waste at depot
# -------------272--------------
# Unloading 113.80000000000001 kg of waste at depot
# -------------273--------------
# Unloading 123.6 kg of waste at depot
# -------------274--------------
# Unloading 137.1 kg of waste at depot
# -------------275--------------
# Unloading 125.2 kg of waste at depot
# -------------276--------------
# Unloading 136.4 kg of waste at depot
# -------------277--------------
# Unloading 128.1 kg of waste at depot
# -------------278--------------
# Unloading 137.6 kg of waste at depot
# -------------279--------------
# Unloading 127.39999999999999 kg of waste at depot
# -------------280--------------
# Unloading 134.9 kg of waste at depot
# -------------281--------------
# Unloading 128.60000000000002 kg of waste at depot
# -------------282--------------
# Unloading 119.0 kg of waste at depot
# -------------283--------------
# Unloading 123.79999999999998 kg of waste at depot
# -------------284--------------
# Unloading 123.19999999999999 kg of waste at depot
# -------------285--------------
# Unloading 134.20000000000002 kg of waste at depot
# -------------286--------------
# Unloading 129.3 kg of waste at depot
# -------------287--------------
# Unloading 129.29999999999998 kg of waste at depot
# -------------288--------------
# Unloading 132.8 kg of waste at depot
# -------------289--------------
# Unloading 123.19999999999999 kg of waste at depot
# -------------290--------------
# Unloading 124.19999999999999 kg of waste at depot
# -------------291--------------
# Unloading 124.69999999999999 kg of waste at depot
# -------------292--------------
# Unloading 129.0 kg of waste at depot
# -------------293--------------
# Unloading 132.1 kg of waste at depot
# -------------294--------------
# Unloading 119.1 kg of waste at depot
# -------------295--------------
# Unloading 112.30000000000001 kg of waste at depot
# -------------296--------------
# Unloading 129.0 kg of waste at depot
# -------------297--------------
# Unloading 111.1 kg of waste at depot
# -------------298--------------
# Unloading 132.9 kg of waste at depot
# -------------299--------------
# Unloading 121.70000000000002 kg of waste at depot
# -------------300--------------
# Unloading 121.6 kg of waste at depot
# -------------301--------------
# Unloading 137.0 kg of waste at depot
# -------------302--------------
# Unloading 124.10000000000001 kg of waste at depot
# -------------303--------------
# Unloading 117.6 kg of waste at depot
# -------------304--------------
# Unloading 119.40000000000002 kg of waste at depot
# -------------305--------------
# Unloading 132.70000000000002 kg of waste at depot
# -------------306--------------
# Unloading 130.8 kg of waste at depot
# -------------307--------------
# Unloading 137.3 kg of waste at depot
# -------------308--------------
# Unloading 128.49999999999997 kg of waste at depot
# -------------309--------------
# Unloading 137.8 kg of waste at depot
# -------------310--------------
# Unloading 122.3 kg of waste at depot
# -------------311--------------
# Unloading 136.1 kg of waste at depot
# -------------312--------------
# Unloading 125.6 kg of waste at depot
# -------------313--------------
# Unloading 136.10000000000002 kg of waste at depot
# -------------314--------------
# Unloading 134.4 kg of waste at depot
# -------------315--------------
# Unloading 120.30000000000001 kg of waste at depot
# -------------316--------------
# Unloading 138.1 kg of waste at depot
# -------------317--------------
# Unloading 129.4 kg of waste at depot
# -------------318--------------
# Unloading 131.6 kg of waste at depot
# -------------319--------------
# Unloading 131.2 kg of waste at depot
# -------------320--------------
# Unloading 137.1 kg of waste at depot
# -------------321--------------
# Unloading 137.1 kg of waste at depot
# -------------322--------------
# Unloading 126.80000000000001 kg of waste at depot
# -------------323--------------
# Unloading 133.0 kg of waste at depot
# -------------324--------------
# Unloading 116.9 kg of waste at depot
# -------------325--------------
# Unloading 113.60000000000001 kg of waste at depot
# -------------326--------------
# Unloading 114.4 kg of waste at depot
# -------------327--------------
# Unloading 117.6 kg of waste at depot
# -------------328--------------
# Unloading 138.20000000000002 kg of waste at depot
# -------------329--------------
# Unloading 128.79999999999998 kg of waste at depot
# -------------330--------------
# Unloading 128.10000000000002 kg of waste at depot
# -------------331--------------
# Unloading 133.1 kg of waste at depot
# -------------332--------------
# Unloading 138.3 kg of waste at depot
# -------------333--------------
# Unloading 137.3 kg of waste at depot
# -------------334--------------
# Unloading 132.89999999999998 kg of waste at depot
# -------------335--------------
# Unloading 132.9 kg of waste at depot
# -------------336--------------
# Unloading 127.69999999999999 kg of waste at depot
# -------------337--------------
# Unloading 138.10000000000002 kg of waste at depot
# -------------338--------------
# Unloading 132.29999999999998 kg of waste at depot
# -------------339--------------
# Unloading 126.5 kg of waste at depot
# -------------340--------------
# Unloading 121.9 kg of waste at depot
# -------------341--------------
# Unloading 121.19999999999999 kg of waste at depot
# -------------342--------------
# Unloading 123.6 kg of waste at depot
# -------------343--------------
# Unloading 126.8 kg of waste at depot
# -------------344--------------
# Unloading 121.9 kg of waste at depot
# -------------345--------------
# Unloading 135.6 kg of waste at depot
# -------------346--------------
# Unloading 130.3 kg of waste at depot
# -------------347--------------
# Unloading 125.89999999999999 kg of waste at depot
# -------------348--------------
# Unloading 129.0 kg of waste at depot
# -------------349--------------
# Unloading 129.9 kg of waste at depot
# -------------350--------------
# Unloading 125.89999999999999 kg of waste at depot
# -------------351--------------
# Unloading 119.7 kg of waste at depot
# -------------352--------------
# Unloading 132.3 kg of waste at depot
# -------------353--------------
# Unloading 126.7 kg of waste at depot
# -------------354--------------
# Unloading 125.7 kg of waste at depot
# -------------355--------------
# Unloading 118.69999999999999 kg of waste at depot
# -------------356--------------
# Unloading 129.3 kg of waste at depot
# -------------357--------------
# Unloading 121.6 kg of waste at depot
# -------------358--------------
# Unloading 131.2 kg of waste at depot
# -------------359--------------
# Unloading 138.20000000000002 kg of waste at depot
# -------------360--------------
# Unloading 123.5 kg of waste at depot
# -------------361--------------
# Unloading 131.50000000000003 kg of waste at depot
# -------------362--------------
# Unloading 119.80000000000001 kg of waste at depot
# -------------363--------------
# Unloading 130.7 kg of waste at depot
# -------------364--------------
# Unloading 130.20000000000002 kg of waste at depot
# -------------365--------------
# Unloading 137.79999999999998 kg of waste at depot
# -------------366--------------
# Unloading 133.2 kg of waste at depot
# -------------367--------------
# Unloading 125.29999999999997 kg of waste at depot
# -------------368--------------
# Unloading 128.7 kg of waste at depot
# -------------369--------------
# Unloading 125.6 kg of waste at depot
# -------------370--------------
# Unloading 134.0 kg of waste at depot
# -------------371--------------
# Unloading 114.1 kg of waste at depot
# -------------372--------------
# Unloading 130.70000000000002 kg of waste at depot
# -------------373--------------
# Unloading 126.1 kg of waste at depot
# -------------374--------------
# Unloading 128.8 kg of waste at depot
# -------------375--------------
# Unloading 122.6 kg of waste at depot
# -------------376--------------
# Unloading 114.49999999999999 kg of waste at depot
# -------------377--------------
# Unloading 131.8 kg of waste at depot
# -------------378--------------
# Unloading 120.19999999999997 kg of waste at depot
# -------------379--------------
# Unloading 122.4 kg of waste at depot
# -------------380--------------
# Unloading 129.70000000000002 kg of waste at depot
# -------------381--------------
# Unloading 131.9 kg of waste at depot
# -------------382--------------
# Unloading 128.2 kg of waste at depot
# -------------383--------------
# Unloading 130.4 kg of waste at depot
# -------------384--------------
# Unloading 125.79999999999998 kg of waste at depot
# -------------385--------------
# Unloading 114.49999999999997 kg of waste at depot
# -------------386--------------
# Unloading 132.6 kg of waste at depot
# -------------387--------------
# Unloading 128.7 kg of waste at depot
# -------------388--------------
# Unloading 120.6 kg of waste at depot
# -------------389--------------
# Unloading 135.7 kg of waste at depot
# -------------390--------------
# Unloading 127.79999999999998 kg of waste at depot
# -------------391--------------
# Unloading 132.3 kg of waste at depot
# -------------392--------------
# Unloading 129.7 kg of waste at depot
# -------------393--------------
# Unloading 137.60000000000002 kg of waste at depot
# -------------394--------------
# Unloading 129.1 kg of waste at depot
# -------------395--------------
# Unloading 134.70000000000002 kg of waste at depot
# -------------396--------------
# Unloading 131.3 kg of waste at depot
# -------------397--------------
# Unloading 138.0 kg of waste at depot
# -------------398--------------
# Unloading 132.89999999999998 kg of waste at depot
# -------------399--------------
# Unloading 132.7 kg of waste at depot
# -------------400--------------
# Unloading 130.1 kg of waste at depot
# -------------401--------------
# Unloading 132.79999999999998 kg of waste at depot
# -------------402--------------
# Unloading 114.4 kg of waste at depot
# -------------403--------------
# Unloading 135.9 kg of waste at depot
# -------------404--------------
# Unloading 138.0 kg of waste at depot
# -------------405--------------
# Unloading 109.69999999999999 kg of waste at depot
# -------------406--------------
# Unloading 126.9 kg of waste at depot
# -------------407--------------
# Unloading 136.9 kg of waste at depot
# -------------408--------------
# Unloading 127.49999999999997 kg of waste at depot
# -------------409--------------
# Unloading 134.79999999999998 kg of waste at depot
# -------------410--------------
# Unloading 133.5 kg of waste at depot
# -------------411--------------
# Unloading 133.4 kg of waste at depot
# -------------412--------------
# Unloading 112.30000000000001 kg of waste at depot
# -------------413--------------
# Unloading 127.60000000000001 kg of waste at depot
# -------------414--------------
# Unloading 137.2 kg of waste at depot
# -------------415--------------
# Unloading 119.99999999999999 kg of waste at depot
# -------------416--------------
# Unloading 125.69999999999999 kg of waste at depot
# -------------417--------------
# Unloading 132.5 kg of waste at depot
# -------------418--------------
# Unloading 130.6 kg of waste at depot
# -------------419--------------
# Unloading 135.4 kg of waste at depot
# -------------420--------------
# Unloading 122.1 kg of waste at depot
# -------------421--------------
# Unloading 121.8 kg of waste at depot
# -------------422--------------
# Unloading 134.70000000000002 kg of waste at depot
# -------------423--------------
# Unloading 137.8 kg of waste at depot
# -------------424--------------
# Unloading 136.0 kg of waste at depot
# -------------425--------------
# Unloading 115.39999999999998 kg of waste at depot
# -------------426--------------
# Unloading 115.6 kg of waste at depot
# -------------427--------------
# Unloading 125.4 kg of waste at depot
# -------------428--------------
# Unloading 136.7 kg of waste at depot
# -------------429--------------
# Unloading 135.8 kg of waste at depot
# -------------430--------------
# Unloading 131.6 kg of waste at depot
# -------------431--------------
# Unloading 124.30000000000001 kg of waste at depot
# -------------432--------------
# Unloading 129.9 kg of waste at depot
# -------------433--------------
# Unloading 137.0 kg of waste at depot
# -------------434--------------
# Unloading 122.3 kg of waste at depot
# -------------435--------------
# Unloading 129.7 kg of waste at depot
# -------------436--------------
# Unloading 134.5 kg of waste at depot
# -------------437--------------
# Unloading 135.1 kg of waste at depot
# -------------438--------------
# Unloading 120.90000000000002 kg of waste at depot
# -------------439--------------
# Unloading 125.0 kg of waste at depot
# -------------440--------------
# Unloading 137.20000000000002 kg of waste at depot
# -------------441--------------
# Unloading 125.0 kg of waste at depot
# -------------442--------------
# Unloading 112.6 kg of waste at depot
# -------------443--------------
# Unloading 136.8 kg of waste at depot
# -------------444--------------
# Unloading 132.1 kg of waste at depot
# -------------445--------------
# Unloading 137.5 kg of waste at depot
# -------------446--------------
# Unloading 124.69999999999999 kg of waste at depot
# -------------447--------------
# Unloading 124.4 kg of waste at depot
# -------------448--------------
# Unloading 113.2 kg of waste at depot
# -------------449--------------
# Unloading 114.00000000000001 kg of waste at depot
# -------------450--------------
# Unloading 121.70000000000002 kg of waste at depot
# -------------451--------------
# Unloading 132.4 kg of waste at depot
# -------------452--------------
# Unloading 121.6 kg of waste at depot
# -------------453--------------
# Unloading 132.7 kg of waste at depot
# -------------454--------------
# Unloading 129.4 kg of waste at depot
# -------------455--------------
# Unloading 121.99999999999999 kg of waste at depot
# -------------456--------------
# Unloading 124.1 kg of waste at depot
# -------------457--------------
# Unloading 131.9 kg of waste at depot
# -------------458--------------
# Unloading 137.6 kg of waste at depot
# -------------459--------------
# Unloading 130.6 kg of waste at depot
# -------------460--------------
# Unloading 128.8 kg of waste at depot
# -------------461--------------
# Unloading 117.5 kg of waste at depot
# -------------462--------------
# Unloading 136.6 kg of waste at depot
# -------------463--------------
# Unloading 119.30000000000001 kg of waste at depot
# -------------464--------------
# Unloading 131.2 kg of waste at depot
# -------------465--------------
# Unloading 136.8 kg of waste at depot
# -------------466--------------
# Unloading 126.5 kg of waste at depot
# -------------467--------------
# Unloading 137.1 kg of waste at depot
# -------------468--------------
# Unloading 135.9 kg of waste at depot
# -------------469--------------
# Unloading 131.10000000000002 kg of waste at depot
# -------------470--------------
# Unloading 131.5 kg of waste at depot
# -------------471--------------
# Unloading 122.6 kg of waste at depot
# -------------472--------------
# Unloading 127.89999999999998 kg of waste at depot
# -------------473--------------
# Unloading 137.39999999999998 kg of waste at depot
# -------------474--------------
# Unloading 138.1 kg of waste at depot
# -------------475--------------
# Unloading 136.6 kg of waste at depot
# -------------476--------------
# Unloading 125.4 kg of waste at depot
# -------------477--------------
# Unloading 135.1 kg of waste at depot
# -------------478--------------
# Unloading 127.3 kg of waste at depot
# -------------479--------------
# Unloading 137.2 kg of waste at depot
# -------------480--------------
# Unloading 125.79999999999998 kg of waste at depot
# -------------481--------------
# Unloading 130.2 kg of waste at depot
# -------------482--------------
# Unloading 132.2 kg of waste at depot
# -------------483--------------
# Unloading 136.0 kg of waste at depot
# -------------484--------------
# Unloading 130.4 kg of waste at depot
# -------------485--------------
# Unloading 134.3 kg of waste at depot
# -------------486--------------
# Unloading 132.1 kg of waste at depot
# -------------487--------------
# Unloading 127.7 kg of waste at depot
# -------------488--------------
# Unloading 136.5 kg of waste at depot
# -------------489--------------
# Unloading 129.1 kg of waste at depot
# -------------490--------------
# Unloading 129.4 kg of waste at depot
# -------------491--------------
# Unloading 128.70000000000002 kg of waste at depot
# -------------492--------------
# Unloading 116.89999999999999 kg of waste at depot
# -------------493--------------
# Unloading 127.9 kg of waste at depot
# -------------494--------------
# Unloading 115.29999999999998 kg of waste at depot
# -------------495--------------
# Unloading 133.20000000000002 kg of waste at depot
# -------------496--------------
# Unloading 134.9 kg of waste at depot
# -------------497--------------
# Unloading 128.4 kg of waste at depot
# -------------498--------------
# Unloading 136.1 kg of waste at depot
# -------------499--------------
# Unloading 118.70000000000002 kg of waste at depot

# %%
d1=prepPlot(routelist)
d1.keys()
# d3=prepPlot(routelist)
# d3.keys()
# Out:
# dict_keys(['x0', 'y0'])

# %%
makemap(d1)

# %%
print(f"Minimum distance learnt by a Agent in a Reinforcement learning environment is {min(distance_cov)} km ")
# Out:
# Minimum distance learnt by a Agent in a Reinforcement learning environment is 159.41269999999992 km

# %% [markdown]
# **Running Multi-agent RL system**

# %%
if __name__ == "__main__":
    episodes=500
    i=0
    
    ag=AgentRL()
    
    ag.ResetParams()
    ag2=AgentRL()
    ag2.ResetParams()
    env=Environment()
    IsEnd=False  

    epsilon=0.8
    
    FINAL_1={}
    FINAL_2={}

    DIST_TOTAL={}
    routelist={}
    routelist0={}
    routelist1={}

    routelist_len=[]
    dist0_cov=[]
    dist1_cov=[]
    mean_dist=[]
    while (i<episodes):
        epsilon = 0.95*epsilon
        print(f"-------------{i}--------------")
        IsEnd=False  
        env=Environment()
        ag.ResetParams()
        ag2.ResetParams()
        env.weight=pd.Series(list(my_df['weight']))
        while (int (sum(env.weight))>0):
            routelist0[i],dist0_covered=ag.Q_Learning(env,epsilon,0)
            routelist1[i],dist1_covered=ag2.Q_Learning(env,epsilon,1)
        
        meandist=(dist0_covered+dist1_covered)/2
        dist0_cov.append(dist0_covered)
        dist1_cov.append(dist1_covered)
        mean_dist.append(meandist)
        routelist_len.append(len(routelist0[0]))
        i +=1
    min_route=routelist_len.index(min(routelist_len))
    routelist[0]=routelist0[min_route]
    routelist[1]=routelist1[min_route]
    plt.plot(dist0_cov)
    plt.plot(dist1_cov)
    plt.plot(mean_dist)
# Out:
# -------------0--------------
# Unloading 318.9 kg of waste at depot
# -------------1--------------
# Unloading 347.40000000000003 kg of waste at depot
# -------------2--------------
# Unloading 493.3 kg of waste at depot
# Unloading 275.1 kg of waste at depot
# -------------3--------------
# Unloading 397.99999999999994 kg of waste at depot
# Unloading 370.40000000000003 kg of waste at depot
# -------------4--------------
# Unloading 331.5 kg of waste at depot
# -------------5--------------
# Unloading 412.6000000000001 kg of waste at depot
# -------------6--------------
# Unloading 321.20000000000005 kg of waste at depot
# -------------7--------------
# Unloading 398.1 kg of waste at depot
# -------------8--------------
# Unloading 388.70000000000005 kg of waste at depot
# Unloading 379.70000000000005 kg of waste at depot
# -------------9--------------
# Unloading 414.49999999999994 kg of waste at depot
# Unloading 353.90000000000003 kg of waste at depot
# -------------10--------------
# Unloading 477.09999999999997 kg of waste at depot
# Unloading 291.3 kg of waste at depot
# -------------11--------------
# Unloading 302.8 kg of waste at depot
# -------------12--------------
# Unloading 373.90000000000003 kg of waste at depot
# -------------13--------------
# Unloading 445.90000000000003 kg of waste at depot
# Unloading 322.5 kg of waste at depot
# -------------14--------------
# Unloading 366.09999999999997 kg of waste at depot
# -------------15--------------
# Unloading 343.4 kg of waste at depot
# -------------16--------------
# Unloading 361.4 kg of waste at depot
# -------------17--------------
# Unloading 385.3 kg of waste at depot
# Unloading 383.1 kg of waste at depot
# -------------18--------------
# Unloading 424.8 kg of waste at depot
# Unloading 343.6 kg of waste at depot
# -------------19--------------
# Unloading 428.50000000000006 kg of waste at depot
# -------------20--------------
# Unloading 395.1 kg of waste at depot
# -------------21--------------
# Unloading 370.00000000000006 kg of waste at depot
# Unloading 398.4 kg of waste at depot
# -------------22--------------
# Unloading 415.7 kg of waste at depot
# -------------23--------------
# Unloading 317.30000000000007 kg of waste at depot
# Unloading 451.1 kg of waste at depot
# -------------24--------------
# Unloading 336.9000000000001 kg of waste at depot
# -------------25--------------
# Unloading 399.19999999999993 kg of waste at depot
# -------------26--------------
# Unloading 421.6000000000001 kg of waste at depot
# Unloading 346.79999999999995 kg of waste at depot
# -------------27--------------
# Unloading 405.2 kg of waste at depot
# Unloading 363.2000000000001 kg of waste at depot
# -------------28--------------
# Unloading 308.5 kg of waste at depot
# Unloading 459.90000000000003 kg of waste at depot
# -------------29--------------
# Unloading 465.59999999999997 kg of waste at depot
# -------------30--------------
# Unloading 429.49999999999994 kg of waste at depot
# Unloading 338.90000000000003 kg of waste at depot
# -------------31--------------
# Unloading 396.6 kg of waste at depot
# Unloading 371.80000000000007 kg of waste at depot
# -------------32--------------
# Unloading 389.2 kg of waste at depot
# -------------33--------------
# Unloading 282.30000000000007 kg of waste at depot
# Unloading 486.0999999999999 kg of waste at depot
# -------------34--------------
# Unloading 329.69999999999993 kg of waste at depot
# -------------35--------------
# Unloading 410.6 kg of waste at depot
# Unloading 357.79999999999995 kg of waste at depot
# -------------36--------------
# Unloading 348.0000000000001 kg of waste at depot
# -------------37--------------
# Unloading 394.4 kg of waste at depot
# Unloading 373.99999999999994 kg of waste at depot
# -------------38--------------
# Unloading 351.3 kg of waste at depot
# Unloading 417.0999999999999 kg of waste at depot
# -------------39--------------
# Unloading 410.70000000000005 kg of waste at depot
# -------------40--------------
# Unloading 443.00000000000006 kg of waste at depot
# -------------41--------------
# Unloading 358.80000000000007 kg of waste at depot
# -------------42--------------
# Unloading 379.5 kg of waste at depot
# Unloading 388.90000000000003 kg of waste at depot
# -------------43--------------
# Unloading 377.6000000000001 kg of waste at depot
# Unloading 390.8 kg of waste at depot
# -------------44--------------
# Unloading 353.29999999999995 kg of waste at depot
# -------------45--------------
# Unloading 497.90000000000003 kg of waste at depot
# -------------46--------------
# Unloading 423.20000000000005 kg of waste at depot
# -------------47--------------
# Unloading 326.40000000000003 kg of waste at depot
# Unloading 442.0 kg of waste at depot
# -------------48--------------
# Unloading 357.3999999999999 kg of waste at depot
# -------------49--------------
# Unloading 349.7 kg of waste at depot
# -------------50--------------
# Unloading 396.49999999999994 kg of waste at depot
# -------------51--------------
# Unloading 376.70000000000005 kg of waste at depot
# -------------52--------------
# Unloading 354.8 kg of waste at depot
# Unloading 413.6 kg of waste at depot
# -------------53--------------
# Unloading 428.7000000000001 kg of waste at depot
# -------------54--------------
# Unloading 371.40000000000003 kg of waste at depot
# Unloading 397.00000000000006 kg of waste at depot
# -------------55--------------
# Unloading 321.7000000000001 kg of waste at depot
# -------------56--------------
# Unloading 395.5 kg of waste at depot
# Unloading 372.90000000000003 kg of waste at depot
# -------------57--------------
# Unloading 429.5 kg of waste at depot
# -------------58--------------
# Unloading 395.0 kg of waste at depot
# -------------59--------------
# Unloading 436.0 kg of waste at depot
# Unloading 332.40000000000003 kg of waste at depot
# -------------60--------------
# Unloading 414.0999999999999 kg of waste at depot
# Unloading 354.3 kg of waste at depot
# -------------61--------------
# Unloading 364.7 kg of waste at depot
# Unloading 403.7 kg of waste at depot
# -------------62--------------
# Unloading 387.8 kg of waste at depot
# Unloading 380.59999999999997 kg of waste at depot
# -------------63--------------
# Unloading 348.40000000000003 kg of waste at depot
# Unloading 420.0 kg of waste at depot
# -------------64--------------
# Unloading 409.69999999999993 kg of waste at depot
# Unloading 358.70000000000005 kg of waste at depot
# -------------65--------------
# Unloading 340.49999999999994 kg of waste at depot
# Unloading 427.9 kg of waste at depot
# -------------66--------------
# Unloading 331.0000000000001 kg of waste at depot
# Unloading 437.3999999999999 kg of waste at depot
# -------------67--------------
# Unloading 338.6000000000001 kg of waste at depot
# -------------68--------------
# Unloading 379.2 kg of waste at depot
# -------------69--------------
# Unloading 374.6000000000001 kg of waste at depot
# -------------70--------------
# Unloading 464.4000000000001 kg of waste at depot
# -------------71--------------
# Unloading 422.50000000000006 kg of waste at depot
# Unloading 345.90000000000003 kg of waste at depot
# -------------72--------------
# Unloading 308.8 kg of waste at depot
# -------------73--------------
# Unloading 360.6000000000001 kg of waste at depot
# -------------74--------------
# Unloading 442.1000000000001 kg of waste at depot
# Unloading 326.3 kg of waste at depot
# -------------75--------------
# Unloading 411.90000000000003 kg of waste at depot
# -------------76--------------
# Unloading 422.59999999999997 kg of waste at depot
# -------------77--------------
# Unloading 392.19999999999993 kg of waste at depot
# Unloading 376.20000000000005 kg of waste at depot
# -------------78--------------
# Unloading 435.8999999999999 kg of waste at depot
# Unloading 332.5 kg of waste at depot
# -------------79--------------
# Unloading 438.79999999999995 kg of waste at depot
# -------------80--------------
# Unloading 366.4 kg of waste at depot
# Unloading 402.0 kg of waste at depot
# -------------81--------------
# Unloading 380.69999999999993 kg of waste at depot
# Unloading 387.70000000000005 kg of waste at depot
# -------------82--------------
# Unloading 439.9 kg of waste at depot
# -------------83--------------
# Unloading 394.80000000000007 kg of waste at depot
# Unloading 373.6 kg of waste at depot
# -------------84--------------
# Unloading 392.1 kg of waste at depot
# -------------85--------------
# Unloading 314.50000000000006 kg of waste at depot
# -------------86--------------
# Unloading 423.1000000000001 kg of waste at depot
# -------------87--------------
# Unloading 309.6 kg of waste at depot
# -------------88--------------
# Unloading 448.5 kg of waste at depot
# -------------89--------------
# Unloading 491.29999999999995 kg of waste at depot
# Unloading 277.1 kg of waste at depot
# -------------90--------------
# Unloading 424.4000000000001 kg of waste at depot
# -------------91--------------
# Unloading 391.8999999999999 kg of waste at depot
# Unloading 376.5 kg of waste at depot
# -------------92--------------
# Unloading 339.20000000000005 kg of waste at depot
# Unloading 429.2 kg of waste at depot
# -------------93--------------
# Unloading 382.8 kg of waste at depot
# Unloading 385.59999999999997 kg of waste at depot
# -------------94--------------
# Unloading 392.00000000000006 kg of waste at depot
# -------------95--------------
# Unloading 365.1 kg of waste at depot
# Unloading 403.30000000000007 kg of waste at depot
# -------------96--------------
# Unloading 403.90000000000003 kg of waste at depot
# Unloading 364.50000000000006 kg of waste at depot
# -------------97--------------
# Unloading 429.1 kg of waste at depot
# Unloading 339.30000000000007 kg of waste at depot
# -------------98--------------
# Unloading 324.00000000000006 kg of waste at depot
# Unloading 444.3999999999999 kg of waste at depot
# -------------99--------------
# Unloading 361.60000000000014 kg of waste at depot
# -------------100--------------
# Unloading 398.9000000000001 kg of waste at depot
# Unloading 369.5000000000001 kg of waste at depot
# -------------101--------------
# Unloading 454.8 kg of waste at depot
# Unloading 313.6 kg of waste at depot
# -------------102--------------
# Unloading 359.4 kg of waste at depot
# -------------103--------------
# Unloading 409.40000000000003 kg of waste at depot
# Unloading 359.0 kg of waste at depot
# -------------104--------------
# Unloading 433.09999999999997 kg of waste at depot
# -------------105--------------
# Unloading 387.40000000000003 kg of waste at depot
# -------------106--------------
# Unloading 412.6 kg of waste at depot
# Unloading 355.79999999999995 kg of waste at depot
# -------------107--------------
# Unloading 344.09999999999997 kg of waste at depot
# -------------108--------------
# Unloading 379.69999999999993 kg of waste at depot
# Unloading 388.7 kg of waste at depot
# -------------109--------------
# Unloading 370.2 kg of waste at depot
# Unloading 398.20000000000005 kg of waste at depot
# -------------110--------------
# Unloading 471.80000000000007 kg of waste at depot
# Unloading 296.6000000000001 kg of waste at depot
# -------------111--------------
# Unloading 416.79999999999995 kg of waste at depot
# -------------112--------------
# Unloading 456.6000000000001 kg of waste at depot
# -------------113--------------
# Unloading 382.90000000000003 kg of waste at depot
# Unloading 385.5 kg of waste at depot
# -------------114--------------
# Unloading 385.4 kg of waste at depot
# Unloading 383.00000000000006 kg of waste at depot
# -------------115--------------
# Unloading 368.20000000000005 kg of waste at depot
# Unloading 400.2 kg of waste at depot
# -------------116--------------
# Unloading 388.7 kg of waste at depot
# -------------117--------------
# Unloading 411.70000000000005 kg of waste at depot
# Unloading 356.7 kg of waste at depot
# -------------118--------------
# Unloading 377.8999999999999 kg of waste at depot
# Unloading 390.5 kg of waste at depot
# -------------119--------------
# Unloading 363.0 kg of waste at depot
# Unloading 405.4 kg of waste at depot
# -------------120--------------
# Unloading 520.6 kg of waste at depot
# Unloading 247.79999999999998 kg of waste at depot
# -------------121--------------
# Unloading 387.29999999999995 kg of waste at depot
# -------------122--------------
# Unloading 409.69999999999993 kg of waste at depot
# Unloading 358.7000000000001 kg of waste at depot
# -------------123--------------
# Unloading 405.9 kg of waste at depot
# Unloading 362.50000000000006 kg of waste at depot
# -------------124--------------
# Unloading 374.0 kg of waste at depot
# -------------125--------------
# Unloading 437.5999999999999 kg of waste at depot
# Unloading 330.8 kg of waste at depot
# -------------126--------------
# Unloading 253.90000000000003 kg of waste at depot
# -------------127--------------
# Unloading 453.20000000000005 kg of waste at depot
# Unloading 315.2 kg of waste at depot
# -------------128--------------
# Unloading 406.8 kg of waste at depot
# Unloading 361.6 kg of waste at depot
# -------------129--------------
# Unloading 424.50000000000006 kg of waste at depot
# Unloading 343.90000000000003 kg of waste at depot
# -------------130--------------
# Unloading 339.80000000000007 kg of waste at depot
# -------------131--------------
# Unloading 341.49999999999994 kg of waste at depot
# -------------132--------------
# Unloading 484.59999999999997 kg of waste at depot
# Unloading 283.8 kg of waste at depot
# -------------133--------------
# Unloading 401.49999999999994 kg of waste at depot
# -------------134--------------
# Unloading 437.9 kg of waste at depot
# -------------135--------------
# Unloading 353.00000000000006 kg of waste at depot
# Unloading 415.4 kg of waste at depot
# -------------136--------------
# Unloading 385.1 kg of waste at depot
# -------------137--------------
# Unloading 323.30000000000007 kg of waste at depot
# Unloading 445.1000000000001 kg of waste at depot
# -------------138--------------
# Unloading 383.0000000000001 kg of waste at depot
# -------------139--------------
# Unloading 365.9000000000001 kg of waste at depot
# Unloading 402.50000000000006 kg of waste at depot
# -------------140--------------
# Unloading 361.90000000000003 kg of waste at depot
# -------------141--------------
# Unloading 334.2000000000001 kg of waste at depot
# -------------142--------------
# Unloading 469.1 kg of waste at depot
# -------------143--------------
# Unloading 410.20000000000005 kg of waste at depot
# Unloading 358.1999999999999 kg of waste at depot
# -------------144--------------
# Unloading 381.90000000000003 kg of waste at depot
# -------------145--------------
# Unloading 407.8 kg of waste at depot
# -------------146--------------
# Unloading 387.1 kg of waste at depot
# -------------147--------------
# Unloading 407.30000000000007 kg of waste at depot
# Unloading 361.1 kg of waste at depot
# -------------148--------------
# Unloading 406.3 kg of waste at depot
# -------------149--------------
# Unloading 380.70000000000005 kg of waste at depot
# Unloading 387.7 kg of waste at depot
# -------------150--------------
# Unloading 399.6 kg of waste at depot
# -------------151--------------
# Unloading 400.79999999999995 kg of waste at depot
# Unloading 367.6 kg of waste at depot
# -------------152--------------
# Unloading 374.5000000000001 kg of waste at depot
# Unloading 393.9 kg of waste at depot
# -------------153--------------
# Unloading 452.80000000000007 kg of waste at depot
# Unloading 315.59999999999997 kg of waste at depot
# -------------154--------------
# Unloading 364.1 kg of waste at depot
# Unloading 404.2999999999999 kg of waste at depot
# -------------155--------------
# Unloading 452.4 kg of waste at depot
# Unloading 316.00000000000006 kg of waste at depot
# -------------156--------------
# Unloading 397.90000000000003 kg of waste at depot
# Unloading 370.49999999999994 kg of waste at depot
# -------------157--------------
# Unloading 447.40000000000003 kg of waste at depot
# Unloading 321.00000000000006 kg of waste at depot
# -------------158--------------
# Unloading 536.5 kg of waste at depot
# Unloading 231.89999999999998 kg of waste at depot
# -------------159--------------
# Unloading 371.70000000000005 kg of waste at depot
# -------------160--------------
# Unloading 427.3000000000001 kg of waste at depot
# Unloading 341.1 kg of waste at depot
# -------------161--------------
# Unloading 343.7 kg of waste at depot
# Unloading 424.7 kg of waste at depot
# -------------162--------------
# Unloading 337.7 kg of waste at depot
# -------------163--------------
# Unloading 405.4 kg of waste at depot
# Unloading 363.0 kg of waste at depot
# -------------164--------------
# Unloading 394.4000000000001 kg of waste at depot
# -------------165--------------
# Unloading 379.20000000000005 kg of waste at depot
# -------------166--------------
# Unloading 297.1 kg of waste at depot
# Unloading 471.29999999999995 kg of waste at depot
# -------------167--------------
# Unloading 339.30000000000007 kg of waste at depot
# Unloading 429.1 kg of waste at depot
# -------------168--------------
# Unloading 416.29999999999995 kg of waste at depot
# -------------169--------------
# Unloading 359.7000000000001 kg of waste at depot
# -------------170--------------
# Unloading 359.5 kg of waste at depot
# Unloading 408.9 kg of waste at depot
# -------------171--------------
# Unloading 341.1000000000001 kg of waste at depot
# Unloading 427.29999999999995 kg of waste at depot
# -------------172--------------
# Unloading 339.59999999999997 kg of waste at depot
# Unloading 428.8 kg of waste at depot
# -------------173--------------
# Unloading 439.30000000000007 kg of waste at depot
# -------------174--------------
# Unloading 376.19999999999993 kg of waste at depot
# -------------175--------------
# Unloading 418.7999999999999 kg of waste at depot
# Unloading 349.6 kg of waste at depot
# -------------176--------------
# Unloading 395.79999999999995 kg of waste at depot
# -------------177--------------
# Unloading 406.90000000000003 kg of waste at depot
# Unloading 361.49999999999994 kg of waste at depot
# -------------178--------------
# Unloading 472.3 kg of waste at depot
# Unloading 296.1 kg of waste at depot
# -------------179--------------
# Unloading 421.2 kg of waste at depot
# -------------180--------------
# Unloading 435.50000000000006 kg of waste at depot
# Unloading 332.9 kg of waste at depot
# -------------181--------------
# Unloading 383.99999999999994 kg of waste at depot
# Unloading 384.4000000000001 kg of waste at depot
# -------------182--------------
# Unloading 389.40000000000003 kg of waste at depot
# Unloading 379.0 kg of waste at depot
# -------------183--------------
# Unloading 269.6000000000001 kg of waste at depot
# -------------184--------------
# Unloading 463.3 kg of waste at depot
# -------------185--------------
# Unloading 382.2000000000001 kg of waste at depot
# Unloading 386.20000000000005 kg of waste at depot
# -------------186--------------
# Unloading 358.6 kg of waste at depot
# -------------187--------------
# Unloading 443.9 kg of waste at depot
# -------------188--------------
# Unloading 375.7000000000001 kg of waste at depot
# -------------189--------------
# Unloading 357.40000000000003 kg of waste at depot
# -------------190--------------
# Unloading 441.7 kg of waste at depot
# -------------191--------------
# Unloading 341.30000000000007 kg of waste at depot
# -------------192--------------
# Unloading 380.7 kg of waste at depot
# Unloading 387.7 kg of waste at depot
# -------------193--------------
# Unloading 436.7999999999999 kg of waste at depot
# Unloading 331.6 kg of waste at depot
# -------------194--------------
# Unloading 285.9 kg of waste at depot
# Unloading 482.49999999999994 kg of waste at depot
# -------------195--------------
# Unloading 399.9 kg of waste at depot
# -------------196--------------
# Unloading 359.6000000000001 kg of waste at depot
# Unloading 408.8 kg of waste at depot
# -------------197--------------
# Unloading 362.6 kg of waste at depot
# Unloading 405.79999999999995 kg of waste at depot
# -------------198--------------
# Unloading 341.1 kg of waste at depot
# Unloading 427.29999999999995 kg of waste at depot
# -------------199--------------
# Unloading 448.79999999999995 kg of waste at depot
# Unloading 319.6000000000001 kg of waste at depot
# -------------200--------------
# Unloading 358.70000000000005 kg of waste at depot
# -------------201--------------
# Unloading 327.0 kg of waste at depot
# Unloading 441.4000000000001 kg of waste at depot
# -------------202--------------
# Unloading 371.8 kg of waste at depot
# -------------203--------------
# Unloading 317.50000000000006 kg of waste at depot
# Unloading 450.9 kg of waste at depot
# -------------204--------------
# Unloading 361.09999999999997 kg of waste at depot
# -------------205--------------
# Unloading 422.8 kg of waste at depot
# -------------206--------------
# Unloading 403.59999999999997 kg of waste at depot
# -------------207--------------
# Unloading 320.80000000000007 kg of waste at depot
# Unloading 447.59999999999997 kg of waste at depot
# -------------208--------------
# Unloading 344.09999999999997 kg of waste at depot
# Unloading 424.30000000000007 kg of waste at depot
# -------------209--------------
# Unloading 418.19999999999993 kg of waste at depot
# Unloading 350.20000000000005 kg of waste at depot
# -------------210--------------
# Unloading 444.9 kg of waste at depot
# Unloading 323.5 kg of waste at depot
# -------------211--------------
# Unloading 457.7 kg of waste at depot
# Unloading 310.7 kg of waste at depot
# -------------212--------------
# Unloading 382.3 kg of waste at depot
# Unloading 386.1 kg of waste at depot
# -------------213--------------
# Unloading 392.70000000000005 kg of waste at depot
# Unloading 375.70000000000005 kg of waste at depot
# -------------214--------------
# Unloading 374.6 kg of waste at depot
# Unloading 393.8 kg of waste at depot
# -------------215--------------
# Unloading 333.99999999999994 kg of waste at depot
# -------------216--------------
# Unloading 414.2999999999999 kg of waste at depot
# Unloading 354.1 kg of waste at depot
# -------------217--------------
# Unloading 404.20000000000005 kg of waste at depot
# Unloading 364.20000000000005 kg of waste at depot
# -------------218--------------
# Unloading 417.69999999999993 kg of waste at depot
# -------------219--------------
# Unloading 362.0000000000001 kg of waste at depot
# -------------220--------------
# Unloading 389.2 kg of waste at depot
# -------------221--------------
# Unloading 332.20000000000005 kg of waste at depot
# Unloading 436.20000000000005 kg of waste at depot
# -------------222--------------
# Unloading 390.0 kg of waste at depot
# Unloading 378.4000000000001 kg of waste at depot
# -------------223--------------
# Unloading 346.5000000000001 kg of waste at depot
# -------------224--------------
# Unloading 441.4 kg of waste at depot
# -------------225--------------
# Unloading 341.8 kg of waste at depot
# Unloading 426.5999999999999 kg of waste at depot
# -------------226--------------
# Unloading 390.2 kg of waste at depot
# -------------227--------------
# Unloading 408.7000000000001 kg of waste at depot
# Unloading 359.7 kg of waste at depot
# -------------228--------------
# Unloading 428.7000000000001 kg of waste at depot
# -------------229--------------
# Unloading 385.49999999999994 kg of waste at depot
# -------------230--------------
# Unloading 365.7000000000001 kg of waste at depot
# Unloading 402.69999999999993 kg of waste at depot
# -------------231--------------
# Unloading 409.79999999999995 kg of waste at depot
# Unloading 358.59999999999997 kg of waste at depot
# -------------232--------------
# Unloading 405.0 kg of waste at depot
# Unloading 363.4000000000001 kg of waste at depot
# -------------233--------------
# Unloading 408.5 kg of waste at depot
# Unloading 359.90000000000003 kg of waste at depot
# -------------234--------------
# Unloading 366.09999999999997 kg of waste at depot
# Unloading 402.3 kg of waste at depot
# -------------235--------------
# Unloading 420.6 kg of waste at depot
# Unloading 347.79999999999995 kg of waste at depot
# -------------236--------------
# Unloading 399.00000000000006 kg of waste at depot
# Unloading 369.40000000000003 kg of waste at depot
# -------------237--------------
# Unloading 384.2 kg of waste at depot
# -------------238--------------
# Unloading 390.9 kg of waste at depot
# Unloading 377.49999999999994 kg of waste at depot
# -------------239--------------
# Unloading 501.9000000000001 kg of waste at depot
# -------------240--------------
# Unloading 339.29999999999995 kg of waste at depot
# Unloading 429.09999999999997 kg of waste at depot
# -------------241--------------
# Unloading 315.6 kg of waste at depot
# Unloading 452.8 kg of waste at depot
# -------------242--------------
# Unloading 354.8 kg of waste at depot
# Unloading 413.6 kg of waste at depot
# -------------243--------------
# Unloading 389.20000000000005 kg of waste at depot
# Unloading 379.2 kg of waste at depot
# -------------244--------------
# Unloading 442.3 kg of waste at depot
# Unloading 326.1 kg of waste at depot
# -------------245--------------
# Unloading 431.6 kg of waste at depot
# -------------246--------------
# Unloading 477.1000000000001 kg of waste at depot
# Unloading 291.3 kg of waste at depot
# -------------247--------------
# Unloading 426.8 kg of waste at depot
# Unloading 341.59999999999997 kg of waste at depot
# -------------248--------------
# Unloading 411.1 kg of waste at depot
# Unloading 357.2999999999999 kg of waste at depot
# -------------249--------------
# Unloading 446.20000000000005 kg of waste at depot
# Unloading 322.2 kg of waste at depot
# -------------250--------------
# Unloading 332.0 kg of waste at depot
# -------------251--------------
# Unloading 312.69999999999993 kg of waste at depot
# Unloading 455.7 kg of waste at depot
# -------------252--------------
# Unloading 374.30000000000007 kg of waste at depot
# Unloading 394.1 kg of waste at depot
# -------------253--------------
# Unloading 363.5 kg of waste at depot
# -------------254--------------
# Unloading 331.40000000000003 kg of waste at depot
# Unloading 437.0 kg of waste at depot
# -------------255--------------
# Unloading 344.9000000000001 kg of waste at depot
# -------------256--------------
# Unloading 404.90000000000003 kg of waste at depot
# Unloading 363.49999999999994 kg of waste at depot
# -------------257--------------
# Unloading 335.4 kg of waste at depot
# Unloading 433.00000000000006 kg of waste at depot
# -------------258--------------
# Unloading 332.90000000000003 kg of waste at depot
# -------------259--------------
# Unloading 420.70000000000005 kg of waste at depot
# Unloading 347.70000000000005 kg of waste at depot
# -------------260--------------
# Unloading 475.00000000000017 kg of waste at depot
# -------------261--------------
# Unloading 414.00000000000006 kg of waste at depot
# -------------262--------------
# Unloading 351.50000000000006 kg of waste at depot
# -------------263--------------
# Unloading 375.30000000000007 kg of waste at depot
# -------------264--------------
# Unloading 400.5 kg of waste at depot
# -------------265--------------
# Unloading 437.10000000000014 kg of waste at depot
# Unloading 331.3 kg of waste at depot
# -------------266--------------
# Unloading 418.4000000000001 kg of waste at depot
# Unloading 350.0 kg of waste at depot
# -------------267--------------
# Unloading 443.7000000000001 kg of waste at depot
# -------------268--------------
# Unloading 423.70000000000016 kg of waste at depot
# -------------269--------------
# Unloading 443.3 kg of waste at depot
# Unloading 325.1 kg of waste at depot
# -------------270--------------
# Unloading 390.3 kg of waste at depot
# -------------271--------------
# Unloading 356.7 kg of waste at depot
# -------------272--------------
# Unloading 443.6000000000001 kg of waste at depot
# Unloading 324.80000000000007 kg of waste at depot
# -------------273--------------
# Unloading 391.8 kg of waste at depot
# -------------274--------------
# Unloading 438.70000000000005 kg of waste at depot
# Unloading 329.7 kg of waste at depot
# -------------275--------------
# Unloading 314.3 kg of waste at depot
# Unloading 454.1 kg of waste at depot
# -------------276--------------
# Unloading 406.1 kg of waste at depot
# Unloading 362.3 kg of waste at depot
# -------------277--------------
# Unloading 376.7999999999999 kg of waste at depot
# Unloading 391.6 kg of waste at depot
# -------------278--------------
# Unloading 413.49999999999994 kg of waste at depot
# -------------279--------------
# Unloading 470.7 kg of waste at depot
# Unloading 297.69999999999993 kg of waste at depot
# -------------280--------------
# Unloading 442.7 kg of waste at depot
# -------------281--------------
# Unloading 353.09999999999997 kg of waste at depot
# -------------282--------------
# Unloading 453.40000000000003 kg of waste at depot
# -------------283--------------
# Unloading 418.9 kg of waste at depot
# -------------284--------------
# Unloading 300.3 kg of waste at depot
# -------------285--------------
# Unloading 426.8000000000001 kg of waste at depot
# Unloading 341.6 kg of waste at depot
# -------------286--------------
# Unloading 315.09999999999997 kg of waste at depot
# Unloading 453.29999999999995 kg of waste at depot
# -------------287--------------
# Unloading 330.9000000000001 kg of waste at depot
# Unloading 437.50000000000006 kg of waste at depot
# -------------288--------------
# Unloading 463.79999999999995 kg of waste at depot
# Unloading 304.59999999999997 kg of waste at depot
# -------------289--------------
# Unloading 362.1000000000001 kg of waste at depot
# Unloading 406.3000000000001 kg of waste at depot
# -------------290--------------
# Unloading 401.2999999999999 kg of waste at depot
# Unloading 367.1 kg of waste at depot
# -------------291--------------
# Unloading 418.90000000000003 kg of waste at depot
# -------------292--------------
# Unloading 348.2 kg of waste at depot
# Unloading 420.2 kg of waste at depot
# -------------293--------------
# Unloading 383.90000000000003 kg of waste at depot
# Unloading 384.5 kg of waste at depot
# -------------294--------------
# Unloading 379.19999999999993 kg of waste at depot
# -------------295--------------
# Unloading 386.0 kg of waste at depot
# Unloading 382.40000000000003 kg of waste at depot
# -------------296--------------
# Unloading 342.6 kg of waste at depot
# -------------297--------------
# Unloading 355.3 kg of waste at depot
# -------------298--------------
# Unloading 440.2 kg of waste at depot
# Unloading 328.20000000000005 kg of waste at depot
# -------------299--------------
# Unloading 440.7 kg of waste at depot
# Unloading 327.7 kg of waste at depot
# -------------300--------------
# Unloading 411.6 kg of waste at depot
# -------------301--------------
# Unloading 366.79999999999995 kg of waste at depot
# -------------302--------------
# Unloading 447.00000000000006 kg of waste at depot
# Unloading 321.40000000000003 kg of waste at depot
# -------------303--------------
# Unloading 403.20000000000005 kg of waste at depot
# -------------304--------------
# Unloading 336.1 kg of waste at depot
# Unloading 432.3 kg of waste at depot
# -------------305--------------
# Unloading 367.5 kg of waste at depot
# Unloading 400.90000000000003 kg of waste at depot
# -------------306--------------
# Unloading 435.00000000000006 kg of waste at depot
# Unloading 333.4000000000001 kg of waste at depot
# -------------307--------------
# Unloading 335.09999999999997 kg of waste at depot
# -------------308--------------
# Unloading 369.00000000000006 kg of waste at depot
# -------------309--------------
# Unloading 377.80000000000007 kg of waste at depot
# Unloading 390.6000000000001 kg of waste at depot
# -------------310--------------
# Unloading 421.09999999999997 kg of waste at depot
# Unloading 347.3 kg of waste at depot
# -------------311--------------
# Unloading 369.90000000000003 kg of waste at depot
# -------------312--------------
# Unloading 366.20000000000005 kg of waste at depot
# Unloading 402.2 kg of waste at depot
# -------------313--------------
# Unloading 338.8999999999999 kg of waste at depot
# Unloading 429.50000000000006 kg of waste at depot
# -------------314--------------
# Unloading 439.0 kg of waste at depot
# Unloading 329.40000000000003 kg of waste at depot
# -------------315--------------
# Unloading 355.99999999999994 kg of waste at depot
# -------------316--------------
# Unloading 385.30000000000007 kg of waste at depot
# -------------317--------------
# Unloading 386.6 kg of waste at depot
# -------------318--------------
# Unloading 466.20000000000005 kg of waste at depot
# -------------319--------------
# Unloading 391.50000000000006 kg of waste at depot
# -------------320--------------
# Unloading 429.69999999999993 kg of waste at depot
# Unloading 338.70000000000005 kg of waste at depot
# -------------321--------------
# Unloading 339.0 kg of waste at depot
# -------------322--------------
# Unloading 408.1000000000001 kg of waste at depot
# -------------323--------------
# Unloading 418.40000000000003 kg of waste at depot
# -------------324--------------
# Unloading 343.9 kg of waste at depot
# -------------325--------------
# Unloading 433.19999999999993 kg of waste at depot
# Unloading 335.20000000000005 kg of waste at depot
# -------------326--------------
# Unloading 415.09999999999997 kg of waste at depot
# Unloading 353.30000000000007 kg of waste at depot
# -------------327--------------
# Unloading 363.2 kg of waste at depot
# Unloading 405.2 kg of waste at depot
# -------------328--------------
# Unloading 341.09999999999997 kg of waste at depot
# Unloading 427.3000000000001 kg of waste at depot
# -------------329--------------
# Unloading 333.40000000000003 kg of waste at depot
# -------------330--------------
# Unloading 442.79999999999995 kg of waste at depot
# Unloading 325.6000000000001 kg of waste at depot
# -------------331--------------
# Unloading 446.30000000000007 kg of waste at depot
# -------------332--------------
# Unloading 396.09999999999997 kg of waste at depot
# Unloading 372.29999999999995 kg of waste at depot
# -------------333--------------
# Unloading 340.8 kg of waste at depot
# Unloading 427.6 kg of waste at depot
# -------------334--------------
# Unloading 478.70000000000005 kg of waste at depot
# Unloading 289.70000000000005 kg of waste at depot
# -------------335--------------
# Unloading 420.79999999999995 kg of waste at depot
# -------------336--------------
# Unloading 299.40000000000003 kg of waste at depot
# -------------337--------------
# Unloading 460.20000000000005 kg of waste at depot
# -------------338--------------
# Unloading 334.09999999999997 kg of waste at depot
# -------------339--------------
# Unloading 373.09999999999997 kg of waste at depot
# Unloading 395.30000000000007 kg of waste at depot
# -------------340--------------
# Unloading 432.8 kg of waste at depot
# Unloading 335.6000000000001 kg of waste at depot
# -------------341--------------
# Unloading 401.1 kg of waste at depot
# Unloading 367.3 kg of waste at depot
# -------------342--------------
# Unloading 444.59999999999997 kg of waste at depot
# -------------343--------------
# Unloading 427.70000000000005 kg of waste at depot
# Unloading 340.7 kg of waste at depot
# -------------344--------------
# Unloading 351.50000000000006 kg of waste at depot
# Unloading 416.8999999999999 kg of waste at depot
# -------------345--------------
# Unloading 345.30000000000007 kg of waste at depot
# Unloading 423.1000000000001 kg of waste at depot
# -------------346--------------
# Unloading 447.50000000000006 kg of waste at depot
# Unloading 320.9 kg of waste at depot
# -------------347--------------
# Unloading 427.4999999999999 kg of waste at depot
# Unloading 340.90000000000003 kg of waste at depot
# -------------348--------------
# Unloading 292.8 kg of waste at depot
# -------------349--------------
# Unloading 371.6000000000001 kg of waste at depot
# -------------350--------------
# Unloading 405.5999999999999 kg of waste at depot
# Unloading 362.80000000000007 kg of waste at depot
# -------------351--------------
# Unloading 366.6 kg of waste at depot
# Unloading 401.7999999999999 kg of waste at depot
# -------------352--------------
# Unloading 430.0 kg of waste at depot
# Unloading 338.4000000000001 kg of waste at depot
# -------------353--------------
# Unloading 371.40000000000003 kg of waste at depot
# -------------354--------------
# Unloading 416.70000000000005 kg of waste at depot
# -------------355--------------
# Unloading 384.5 kg of waste at depot
# -------------356--------------
# Unloading 378.3000000000001 kg of waste at depot
# Unloading 390.1 kg of waste at depot
# -------------357--------------
# Unloading 357.5 kg of waste at depot
# Unloading 410.9 kg of waste at depot
# -------------358--------------
# Unloading 436.90000000000003 kg of waste at depot
# Unloading 331.50000000000006 kg of waste at depot
# -------------359--------------
# Unloading 369.6 kg of waste at depot
# Unloading 398.80000000000007 kg of waste at depot
# -------------360--------------
# Unloading 356.5 kg of waste at depot
# -------------361--------------
# Unloading 394.5000000000001 kg of waste at depot
# Unloading 373.9 kg of waste at depot
# -------------362--------------
# Unloading 403.5 kg of waste at depot
# -------------363--------------
# Unloading 291.6000000000001 kg of waste at depot
# Unloading 476.79999999999995 kg of waste at depot
# -------------364--------------
# Unloading 363.0 kg of waste at depot
# -------------365--------------
# Unloading 400.00000000000006 kg of waste at depot
# Unloading 368.4000000000001 kg of waste at depot
# -------------366--------------
# Unloading 449.9000000000001 kg of waste at depot
# -------------367--------------
# Unloading 441.50000000000006 kg of waste at depot
# -------------368--------------
# Unloading 354.19999999999993 kg of waste at depot
# Unloading 414.2 kg of waste at depot
# -------------369--------------
# Unloading 338.30000000000007 kg of waste at depot
# Unloading 430.1000000000001 kg of waste at depot
# -------------370--------------
# Unloading 452.5 kg of waste at depot
# Unloading 315.90000000000003 kg of waste at depot
# -------------371--------------
# Unloading 467.50000000000006 kg of waste at depot
# Unloading 300.9 kg of waste at depot
# -------------372--------------
# Unloading 480.7000000000001 kg of waste at depot
# Unloading 287.69999999999993 kg of waste at depot
# -------------373--------------
# Unloading 410.9 kg of waste at depot
# Unloading 357.5 kg of waste at depot
# -------------374--------------
# Unloading 303.20000000000005 kg of waste at depot
# -------------375--------------
# Unloading 360.7 kg of waste at depot
# Unloading 407.70000000000005 kg of waste at depot
# -------------376--------------
# Unloading 391.8000000000001 kg of waste at depot
# Unloading 376.59999999999997 kg of waste at depot
# -------------377--------------
# Unloading 416.20000000000005 kg of waste at depot
# Unloading 352.2 kg of waste at depot
# -------------378--------------
# Unloading 418.20000000000005 kg of waste at depot
# Unloading 350.2 kg of waste at depot
# -------------379--------------
# Unloading 453.50000000000006 kg of waste at depot
# -------------380--------------
# Unloading 399.7000000000001 kg of waste at depot
# Unloading 368.7000000000001 kg of waste at depot
# -------------381--------------
# Unloading 321.7 kg of waste at depot
# -------------382--------------
# Unloading 431.5 kg of waste at depot
# Unloading 336.9 kg of waste at depot
# -------------383--------------
# Unloading 456.70000000000005 kg of waste at depot
# -------------384--------------
# Unloading 367.8999999999999 kg of waste at depot
# -------------385--------------
# Unloading 391.30000000000007 kg of waste at depot
# -------------386--------------
# Unloading 391.8 kg of waste at depot
# Unloading 376.6 kg of waste at depot
# -------------387--------------
# Unloading 361.99999999999994 kg of waste at depot
# Unloading 406.40000000000003 kg of waste at depot
# -------------388--------------
# Unloading 347.1 kg of waste at depot
# Unloading 421.30000000000007 kg of waste at depot
# -------------389--------------
# Unloading 401.99999999999994 kg of waste at depot
# -------------390--------------
# Unloading 422.69999999999993 kg of waste at depot
# -------------391--------------
# Unloading 392.09999999999997 kg of waste at depot
# -------------392--------------
# Unloading 415.0000000000001 kg of waste at depot
# Unloading 353.40000000000003 kg of waste at depot
# -------------393--------------
# Unloading 440.00000000000006 kg of waste at depot
# Unloading 328.40000000000003 kg of waste at depot
# -------------394--------------
# Unloading 421.8 kg of waste at depot
# Unloading 346.6 kg of waste at depot
# -------------395--------------
# Unloading 408.50000000000006 kg of waste at depot
# -------------396--------------
# Unloading 355.4999999999999 kg of waste at depot
# -------------397--------------
# Unloading 345.09999999999997 kg of waste at depot
# -------------398--------------
# Unloading 408.80000000000007 kg of waste at depot
# Unloading 359.6 kg of waste at depot
# -------------399--------------
# Unloading 487.29999999999995 kg of waste at depot
# Unloading 281.1000000000001 kg of waste at depot
# -------------400--------------
# Unloading 441.80000000000007 kg of waste at depot
# Unloading 326.6 kg of waste at depot
# -------------401--------------
# Unloading 464.6 kg of waste at depot
# Unloading 303.8 kg of waste at depot
# -------------402--------------
# Unloading 368.99999999999994 kg of waste at depot
# -------------403--------------
# Unloading 448.80000000000007 kg of waste at depot
# Unloading 319.6000000000001 kg of waste at depot
# -------------404--------------
# Unloading 324.7000000000001 kg of waste at depot
# Unloading 443.7000000000001 kg of waste at depot
# -------------405--------------
# Unloading 355.99999999999994 kg of waste at depot
# -------------406--------------
# Unloading 419.40000000000003 kg of waste at depot
# Unloading 349.0 kg of waste at depot
# -------------407--------------
# Unloading 409.90000000000003 kg of waste at depot
# -------------408--------------
# Unloading 376.40000000000003 kg of waste at depot
# Unloading 392.00000000000006 kg of waste at depot
# -------------409--------------
# Unloading 450.40000000000003 kg of waste at depot
# Unloading 318.00000000000006 kg of waste at depot
# -------------410--------------
# Unloading 379.4 kg of waste at depot
# -------------411--------------
# Unloading 402.49999999999994 kg of waste at depot
# Unloading 365.9000000000001 kg of waste at depot
# -------------412--------------
# Unloading 380.7 kg of waste at depot
# Unloading 387.70000000000005 kg of waste at depot
# -------------413--------------
# Unloading 387.1 kg of waste at depot
# -------------414--------------
# Unloading 365.4 kg of waste at depot
# -------------415--------------
# Unloading 359.80000000000007 kg of waste at depot
# Unloading 408.60000000000014 kg of waste at depot
# -------------416--------------
# Unloading 399.59999999999997 kg of waste at depot
# -------------417--------------
# Unloading 447.3999999999999 kg of waste at depot
# -------------418--------------
# Unloading 379.4 kg of waste at depot
# -------------419--------------
# Unloading 387.0 kg of waste at depot
# -------------420--------------
# Unloading 369.1 kg of waste at depot
# -------------421--------------
# Unloading 360.5 kg of waste at depot
# -------------422--------------
# Unloading 422.59999999999997 kg of waste at depot
# -------------423--------------
# Unloading 400.6 kg of waste at depot
# -------------424--------------
# Unloading 380.3 kg of waste at depot
# Unloading 388.09999999999997 kg of waste at depot
# -------------425--------------
# Unloading 359.90000000000003 kg of waste at depot
# -------------426--------------
# Unloading 296.00000000000006 kg of waste at depot
# -------------427--------------
# Unloading 466.50000000000006 kg of waste at depot
# Unloading 301.9 kg of waste at depot
# -------------428--------------
# Unloading 429.0999999999999 kg of waste at depot
# Unloading 339.30000000000007 kg of waste at depot
# -------------429--------------
# Unloading 433.2 kg of waste at depot
# -------------430--------------
# Unloading 441.30000000000007 kg of waste at depot
# Unloading 327.1 kg of waste at depot
# -------------431--------------
# Unloading 498.49999999999994 kg of waste at depot
# Unloading 269.90000000000003 kg of waste at depot
# -------------432--------------
# Unloading 339.4 kg of waste at depot
# Unloading 429.00000000000006 kg of waste at depot
# -------------433--------------
# Unloading 410.4 kg of waste at depot
# Unloading 357.99999999999994 kg of waste at depot
# -------------434--------------
# Unloading 485.6000000000001 kg of waste at depot
# -------------435--------------
# Unloading 471.1 kg of waste at depot
# -------------436--------------
# Unloading 422.90000000000003 kg of waste at depot
# Unloading 345.50000000000006 kg of waste at depot
# -------------437--------------
# Unloading 499.5 kg of waste at depot
# Unloading 268.90000000000003 kg of waste at depot
# -------------438--------------
# Unloading 385.09999999999997 kg of waste at depot
# Unloading 383.30000000000007 kg of waste at depot
# -------------439--------------
# Unloading 406.8 kg of waste at depot
# Unloading 361.6 kg of waste at depot
# -------------440--------------
# Unloading 376.40000000000003 kg of waste at depot
# Unloading 392.0 kg of waste at depot
# -------------441--------------
# Unloading 454.6000000000001 kg of waste at depot
# Unloading 313.80000000000007 kg of waste at depot
# -------------442--------------
# Unloading 424.70000000000005 kg of waste at depot
# Unloading 343.7 kg of waste at depot
# -------------443--------------
# Unloading 397.20000000000005 kg of waste at depot
# -------------444--------------
# Unloading 450.2999999999999 kg of waste at depot
# Unloading 318.1 kg of waste at depot
# -------------445--------------
# Unloading 345.1 kg of waste at depot
# -------------446--------------
# Unloading 469.00000000000006 kg of waste at depot
# -------------447--------------
# Unloading 424.49999999999994 kg of waste at depot
# Unloading 343.9000000000001 kg of waste at depot
# -------------448--------------
# Unloading 363.40000000000003 kg of waste at depot
# -------------449--------------
# Unloading 393.5 kg of waste at depot
# -------------450--------------
# Unloading 357.30000000000007 kg of waste at depot
# -------------451--------------
# Unloading 362.2 kg of waste at depot
# -------------452--------------
# Unloading 368.3999999999999 kg of waste at depot
# -------------453--------------
# Unloading 371.00000000000006 kg of waste at depot
# -------------454--------------
# Unloading 409.70000000000005 kg of waste at depot
# -------------455--------------
# Unloading 529.4999999999999 kg of waste at depot
# Unloading 238.9 kg of waste at depot
# -------------456--------------
# Unloading 344.1000000000001 kg of waste at depot
# Unloading 424.2999999999999 kg of waste at depot
# -------------457--------------
# Unloading 418.7 kg of waste at depot
# Unloading 349.70000000000005 kg of waste at depot
# -------------458--------------
# Unloading 370.3 kg of waste at depot
# Unloading 398.1 kg of waste at depot
# -------------459--------------
# Unloading 444.1 kg of waste at depot
# Unloading 324.3 kg of waste at depot
# -------------460--------------
# Unloading 391.8 kg of waste at depot
# Unloading 376.6 kg of waste at depot
# -------------461--------------
# Unloading 397.29999999999995 kg of waste at depot
# Unloading 371.1 kg of waste at depot
# -------------462--------------
# Unloading 442.3 kg of waste at depot
# -------------463--------------
# Unloading 432.79999999999995 kg of waste at depot
# -------------464--------------
# Unloading 409.1 kg of waste at depot
# -------------465--------------
# Unloading 338.8999999999999 kg of waste at depot
# -------------466--------------
# Unloading 439.7999999999999 kg of waste at depot
# -------------467--------------
# Unloading 537.8 kg of waste at depot
# Unloading 230.60000000000002 kg of waste at depot
# -------------468--------------
# Unloading 441.50000000000006 kg of waste at depot
# Unloading 326.9 kg of waste at depot
# -------------469--------------
# Unloading 405.20000000000005 kg of waste at depot
# Unloading 363.2 kg of waste at depot
# -------------470--------------
# Unloading 421.8 kg of waste at depot
# Unloading 346.6 kg of waste at depot
# -------------471--------------
# Unloading 402.6 kg of waste at depot
# Unloading 365.8 kg of waste at depot
# -------------472--------------
# Unloading 379.70000000000005 kg of waste at depot
# Unloading 388.7 kg of waste at depot
# -------------473--------------
# Unloading 338.40000000000003 kg of waste at depot
# -------------474--------------
# Unloading 329.90000000000003 kg of waste at depot
# -------------475--------------
# Unloading 416.9000000000001 kg of waste at depot
# Unloading 351.50000000000006 kg of waste at depot
# -------------476--------------
# Unloading 349.6 kg of waste at depot
# -------------477--------------
# Unloading 457.6 kg of waste at depot
# Unloading 310.79999999999995 kg of waste at depot
# -------------478--------------
# Unloading 385.29999999999995 kg of waste at depot
# -------------479--------------
# Unloading 406.4000000000001 kg of waste at depot
# Unloading 361.99999999999994 kg of waste at depot
# -------------480--------------
# Unloading 398.5 kg of waste at depot
# -------------481--------------
# Unloading 342.20000000000005 kg of waste at depot
# Unloading 426.19999999999993 kg of waste at depot
# -------------482--------------
# Unloading 388.19999999999993 kg of waste at depot
# -------------483--------------
# Unloading 394.6 kg of waste at depot
# -------------484--------------
# Unloading 390.80000000000007 kg of waste at depot
# Unloading 377.6 kg of waste at depot
# -------------485--------------
# Unloading 464.0 kg of waste at depot
# -------------486--------------
# Unloading 396.90000000000003 kg of waste at depot
# -------------487--------------
# Unloading 363.69999999999993 kg of waste at depot
# Unloading 404.7000000000001 kg of waste at depot
# -------------488--------------
# Unloading 421.6 kg of waste at depot
# -------------489--------------
# Unloading 256.70000000000005 kg of waste at depot
# Unloading 511.7 kg of waste at depot
# -------------490--------------
# Unloading 315.3 kg of waste at depot
# -------------491--------------
# Unloading 336.6 kg of waste at depot
# -------------492--------------
# Unloading 392.6 kg of waste at depot
# Unloading 375.79999999999995 kg of waste at depot
# -------------493--------------
# Unloading 438.8 kg of waste at depot
# Unloading 329.6 kg of waste at depot
# -------------494--------------
# Unloading 431.20000000000005 kg of waste at depot
# Unloading 337.2 kg of waste at depot
# -------------495--------------
# Unloading 343.69999999999993 kg of waste at depot
# -------------496--------------
# Unloading 370.9 kg of waste at depot
# -------------497--------------
# Unloading 340.1 kg of waste at depot
# -------------498--------------
# Unloading 326.79999999999995 kg of waste at depot
# -------------499--------------
# Unloading 392.90000000000003 kg of waste at depot
# Unloading 375.50000000000006 kg of waste at depot

# %%
d2=prepPlot(routelist)
d2.keys()
# d3=prepPlot(routelist)
# d3.keys()
# Out:
# dict_keys(['x0', 'y0', 'x1', 'y1'])

# %%
makemap(d2)

# %%
print(f"Minimum distance learnt by 2 Agents in a Multi-Agent Reinforcement learning environment is {min(mean_dist)} km ")
# Out:
# Minimum distance learnt by 2 Agents in a Multi-Agent Reinforcement learning environment is 63.40475000000001 km
